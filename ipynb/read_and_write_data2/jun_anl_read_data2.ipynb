# %% [markdown]
# # **18 Чтение и запись данных. Часть 2**

# %% [markdown]
# Курс ведёт **Андрей Мещеряков** Data Scientist в EPAM

# %% [markdown]
# ## **18.1** *Чтение данных JSON из веб-сервисов*
#
# **План модуля**
#
# * Чтение данных JSON из веб-сервисов
# * Чтение и запись файлов в формате JSON
# * Чтение данных из баз данных (при помощи Python, без консоли)
# * Работа с большими данными — MongoDB
# * Домашнее задание
#
# ### JSON
#
# В этом уроке мы узнаем для чего используется формат JSON, научимся читать данные в этом формате из веб-сервисов, а также преобразовывать их в `DataFrame` ***pandas***.
#
# JavaScript Object Notation — нотация объектов JavaScript\
# Пример JSON:
# <pre><code>
#     {
#     "title":"Moscow",
#     "location_type":"City",
#     "woeid":2122265,
#     "latt_long":"55.756950,37.614971"
#     }
# </code></pre>
#
# Этот формат очень похож на словари в Python. И мы будем испльзовать это сходство в дальнейшем. Изначально он использовался только в языке Javascript как синтаксис объектов. Но он оказался настолько удачным, что сейчас стал самостоятельным текстовым форматом, который "из коробки" поддерживается во многих языках, в т.ч. и в Python.\
# Чаще всего JSON используется для обмена данными между устройствами в Интернете, например, между мобильным приложением и сервером. Или между веб-сайтом и его сервером. Или просто между двумя серверами.
#
# Преимущества формата JSON:
# * понятен человеку
# * с ним удобно работать
# * не зависит от языка программирования

# %% [markdown]
# ### Чтение данных из web-сервисов
#
# Любое взаимодействие с web-сервисами состоит из нескольких этапов.
#
# Этапы взаимодействия с веб-сервисом:
# * Клиент отправляет запрос по адресу (URL) сервиса (URL — universal resource locator, универсальный локатор
# ресурсов)
# * Сервис обрабатывает запрос и возвращает результат клиенту (этот этап полностью скрыт от глаз клиента: мы не можем видеть что происходит внутри сервера)
# * Клиент принимает ответ сервера и завершает соединение
#
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8">
#   <title></title>
#   <style>
#    .thumb img  {
#     border: 2px solid #55c5e9; /* Рамка вокруг фотографии */
#     padding: 15px; /* Расстояние от картинки до рамки */
#     background: #666; /* Цвет фона */
#     margin-right: 10px; /* Отступ справа */
#     margin-bottom: 10px; /* Отступ снизу */
#    }
#   </style>
#  </head>
#  <body>
#   <p class="thumb">
#     <img src="img/img1.png" height=700 width=250 alt="Данные мечты" class="thumb">
#     <img src="img/img2.png" height=700 width=252 alt="Данные мечты" class="thumb">
#     <img src="img/img3.png" height=700 width=268 alt="Данные мечты" class="thumb">
#   </p>
#  </body>
# </html>

# %% [markdown]
# #### Поиск данных о погоде в городе при помощи сервиса MetaWeather
#
# Для выполнения запросов к сервису, используем модуль `urllib.request`

# %%
import urllib.request as req
import json
import pandas as pd

# %% [markdown]
# Сформируем запрос к веб-сервису поиска города. Используем следующий адрес веб-сервиса:
#
# #### Поиск идентификатора города

# %%
url = "https://www.metaweather.com/api/location/search/?query=moscow"

session = req.urlopen(url) # сессия связи с сервером
response = session.read().decode() # запишем ответ сервера
session.close() # закрываем соединение с сервером

response
# Out:
# '[{"title":"Moscow","location_type":"City","woeid":2122265,"latt_long":"55.756950,37.614971"}]'

# %% [markdown]
# Как видно, ответ сервера очень похож на словарь.
#
# Важно не забывать закрывать соединение кадждый раз, когда заканчиваем получение ответа от сервера.\
# Если забыть и оставить соединение открытым, то это может вызвать разные неприятные последствия: утечку памяти, сложность использования браузера или др. приложений, использующих Интернет.\
# Закрыть соединение можно двумя способами:
# * использовать метод **`session.close()`**,\
# но есть недостаток у этого метода: можно забыть вызвать метод
# * использовать **менеджер контекста** (ключевое слово `with` при создании сессии).\
# В этом случае, не нужно явно вызывать метод `close` - это будет сделано автоматически как только выполнится блок инструкций внутри `with`.
#
# Перепишем ячейку с использованием инструкции `with`

# %%
url = "https://www.metaweather.com/api/location/search/?query=moscow"

with req.urlopen(url) as session:
    response1 = session.read().decode()
response1
# Out:
# '[{"title":"Moscow","location_type":"City","woeid":2122265,"latt_long":"55.756950,37.614971"}]'

# %% [markdown]
# Готово. И нам не нужно закрывать соединение самостоятельно. Это за нас сделал **менеджер контекста**.
#
# Теперь перейдём к работе с ответом сервера. Он записан в формате JSON.\
# В Python при работе с JSON чаще всего используют два подхода:
# 1. С ним работают как и со словарём, т.к. он сам похож на словарь
# 2. Можно преобразовать его в `DataFrame` **`pandas`**\
# и работать с ним как с другими датафреймами.
#
# Оба подхода используют специальные методы из библиотеки JSON, которые предоставят нам дополнительную функциональность.\
# Преобразуем ответ сервера к словарю. Вызовем функцию `loads` из модуля `json` и передадим ей ответ сервера.

# %%
url = "https://www.metaweather.com/api/location/search/?query=moscow"

with req.urlopen(url) as session:
    response1 = session.read().decode()
    data = json.loads(response1) # присвоим переменной data результат функции loads
data[0] # и выведем её на экран
# Out:
# {'title': 'Moscow',
#  'location_type': 'City',
#  'woeid': 2122265,
#  'latt_long': '55.756950,37.614971'}

# %% [markdown]
# Мы видим список из одного словаря. Такой формат использует сервер для того, чтобы вернуть результат поиска, видимо, на случай, если будет найдено больше одного города.\
# Мы вывели первый элемент этого списка.\
# Итак, мы видим словарь, из которого мы можем получить идентификатор Москвы просто обратившись по ключу `woeid`.\
# Запишем этот идентификтор в переменную `city`

# %%
city = data[0]['woeid']
city
# Out:
# 2122265

# %% [markdown]
# #### Получение истории погоды
#
# Теперь выполним другой запрос, чтобы получить историю погоды в Москве за неделю.\
# Для этого используем следующий адрес:\
# (Здесь мы используем в url идентификатор города, который мы получили в предыдущем запросе. А после идентификатора идёт YYYY/mm/dd, за которые мы хотим получить данные о погоде).
# Преобразуем ответ сервера из строки в словарь и выведем его на экран

# %%
url = 'https://www.metaweather.com/api/location/2122265/2020/07/20/'

with req.urlopen(url) as session:
    response = session.read().decode()
    data = json.loads(response)
data
# Out:
# [{'id': 4919777191526400,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-20T18:29:31.885101Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 16.794999999999998,
#   'max_temp': 24.02,
#   'the_temp': 23.005,
#   'wind_speed': 2.833971496858347,
#   'wind_direction': 300.6971747272375,
#   'air_pressure': 1011.5,
#   'humidity': 66,
#   'visibility': 12.808945756780403,
#   'predictability': 75},
#  {'id': 5843753002598400,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-20T15:29:31.460467Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 16.794999999999998,
#   'max_temp': 24.02,
#   'the_temp': 22.95,
#   'wind_speed': 2.833971496858347,
#   'wind_direction': 300.6971747272375,
#   'air_pressure': 1011.5,
#   'humidity': 66,
#   'visibility': 12.808945756780403,
#   'predictability': 73},
#  {'id': 4695383806574592,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-20T12:29:32.565565Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 16.724999999999998,
#   'max_temp': 23.92,
#   'the_temp': 21.939999999999998,
#   'wind_speed': 2.7411799186696357,
#   'wind_direction': 313.66663657794044,
#   'air_pressure': 1013.0,
#   'humidity': 71,
#   'visibility': 12.808945756780403,
#   'predictability': 73},
#  {'id': 4806990276591616,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-20T09:29:32.257786Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 16.84,
#   'max_temp': 22.765,
#   'the_temp': 21.9,
#   'wind_speed': 2.5419696853363027,
#   'wind_direction': 317.3299021184476,
#   'air_pressure': 1013.0,
#   'humidity': 71,
#   'visibility': 12.501367016622922,
#   'predictability': 73},
#  {'id': 6202314589208576,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-20T06:29:32.073897Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.115,
#   'max_temp': 21.955,
#   'the_temp': 20.64,
#   'wind_speed': 2.3568010490760627,
#   'wind_direction': 328.28048857461255,
#   'air_pressure': 1013.0,
#   'humidity': 69,
#   'visibility': 11.168215123677722,
#   'predictability': 75},
#  {'id': 5224521143418880,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-20T03:29:33.583986Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.375,
#   'max_temp': 22.18,
#   'the_temp': 20.68,
#   'wind_speed': 2.6234677157427293,
#   'wind_direction': 331.35398418937433,
#   'air_pressure': 1013.0,
#   'humidity': 70,
#   'visibility': 11.11508788674143,
#   'predictability': 75},
#  {'id': 5431512780505088,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-20T00:29:32.173478Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.614999999999998,
#   'max_temp': 23.05,
#   'the_temp': 20.93,
#   'wind_speed': 3.7846014417137255,
#   'wind_direction': 330.95708612705266,
#   'air_pressure': 1011.5,
#   'humidity': 64,
#   'visibility': 13.85129593175853,
#   'predictability': 75},
#  {'id': 4761532342730752,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-19T21:29:31.039087Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.614999999999998,
#   'max_temp': 23.05,
#   'the_temp': 21.065,
#   'wind_speed': 3.1284353083803924,
#   'wind_direction': 308.30386836234067,
#   'air_pressure': 1009.5,
#   'humidity': 66,
#   'visibility': 11.261420802513321,
#   'predictability': 75},
#  {'id': 4864295173095424,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-19T18:29:34.844031Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.675,
#   'max_temp': 19.725,
#   'the_temp': 20.22,
#   'wind_speed': 3.585032339526498,
#   'wind_direction': 324.95052346041354,
#   'air_pressure': 1012.5,
#   'humidity': 73,
#   'visibility': 9.874209615843473,
#   'predictability': 75},
#  {'id': 5888541458432000,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-19T15:29:33.982460Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.675,
#   'max_temp': 19.725,
#   'the_temp': 20.2,
#   'wind_speed': 3.577575906193165,
#   'wind_direction': 324.95052346041354,
#   'air_pressure': 1012.5,
#   'humidity': 74,
#   'visibility': 9.571912530820011,
#   'predictability': 75},
#  {'id': 5570326526164992,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-19T12:29:34.058569Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.649999999999999,
#   'max_temp': 19.1,
#   'the_temp': 20.064999999999998,
#   'wind_speed': 3.7432748907897877,
#   'wind_direction': 319.3329905781327,
#   'air_pressure': 1012.5,
#   'humidity': 74,
#   'visibility': 9.252527738010022,
#   'predictability': 77},
#  {'id': 6486747825307648,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-19T09:29:35.338169Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.3,
#   'max_temp': 18.674999999999997,
#   'the_temp': 19.99,
#   'wind_speed': 3.8716953574564545,
#   'wind_direction': 317.3299021184476,
#   'air_pressure': 1012.0,
#   'humidity': 73,
#   'visibility': 9.847801340173387,
#   'predictability': 77},
#  {'id': 6623753423290368,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-19T06:29:34.153016Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.975000000000001,
#   'max_temp': 18.86,
#   'the_temp': 19.49,
#   'wind_speed': 3.712624290296667,
#   'wind_direction': 315.9993901614561,
#   'air_pressure': 1012.0,
#   'humidity': 77,
#   'visibility': 9.149069434502504,
#   'predictability': 77},
#  {'id': 5377824447791104,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-19T03:29:34.547118Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.86,
#   'max_temp': 19.34,
#   'the_temp': 19.485,
#   'wind_speed': 3.9749935902966675,
#   'wind_direction': 313.0064297614647,
#   'air_pressure': 1012.0,
#   'humidity': 78,
#   'visibility': 8.328238089556987,
#   'predictability': 75},
#  {'id': 4958395121532928,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-19T00:29:35.849812Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.530000000000001,
#   'max_temp': 20.060000000000002,
#   'the_temp': 19.185000000000002,
#   'wind_speed': 4.226027824616241,
#   'wind_direction': 297.0,
#   'air_pressure': 1011.0,
#   'humidity': 75,
#   'visibility': 12.806149586415334,
#   'predictability': 75},
#  {'id': 4592018472828928,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-18T21:29:33.964414Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.530000000000001,
#   'max_temp': 20.060000000000002,
#   'the_temp': 19.16,
#   'wind_speed': 4.300592157949574,
#   'wind_direction': 303.0080158152948,
#   'air_pressure': 1009.0,
#   'humidity': 76,
#   'visibility': 11.870675256502029,
#   'predictability': 77},
#  {'id': 6497094837731328,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-18T18:29:38.189563Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.5,
#   'max_temp': 20.82,
#   'the_temp': 20.805,
#   'wind_speed': 3.792148521935894,
#   'wind_direction': 313.3338037204484,
#   'air_pressure': 1012.5,
#   'humidity': 69,
#   'visibility': 12.691817287043666,
#   'predictability': 75},
#  {'id': 5515548781707264,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-18T15:29:38.266512Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.5,
#   'max_temp': 20.82,
#   'the_temp': 20.77,
#   'wind_speed': 3.7623227886025608,
#   'wind_direction': 313.3338037204484,
#   'air_pressure': 1012.5,
#   'humidity': 70,
#   'visibility': 12.901840750019883,
#   'predictability': 75},
#  {'id': 6166102746857472,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-18T12:29:38.942025Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.425,
#   'max_temp': 20.925,
#   'the_temp': 20.735,
#   'wind_speed': 3.685687008226623,
#   'wind_direction': 310.6661282155967,
#   'air_pressure': 1012.5,
#   'humidity': 68,
#   'visibility': 12.615388630398472,
#   'predictability': 75},
#  {'id': 5281846424240128,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-18T09:29:38.063016Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.445,
#   'max_temp': 21.27,
#   'the_temp': 20.759999999999998,
#   'wind_speed': 3.3831434415599566,
#   'wind_direction': 307.9978606740761,
#   'air_pressure': 1012.5,
#   'humidity': 67,
#   'visibility': 11.950832140300644,
#   'predictability': 75},
#  {'id': 6165934974697472,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-18T06:29:38.188082Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.864999999999998,
#   'max_temp': 22.955,
#   'the_temp': 23.09,
#   'wind_speed': 3.2650830199024363,
#   'wind_direction': 307.7345209943367,
#   'air_pressure': 1013.0,
#   'humidity': 62,
#   'visibility': 12.941297820726954,
#   'predictability': 75},
#  {'id': 5314052773380096,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-18T03:29:38.077836Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.844999999999999,
#   'max_temp': 23.345,
#   'the_temp': 23.085,
#   'wind_speed': 3.437626586569103,
#   'wind_direction': 307.3905395389413,
#   'air_pressure': 1012.5,
#   'humidity': 63,
#   'visibility': 13.471638133301518,
#   'predictability': 75},
#  {'id': 5420806500777984,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-18T00:29:37.848180Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.48,
#   'max_temp': 24.29,
#   'the_temp': 23.21,
#   'wind_speed': 3.7764806744929618,
#   'wind_direction': 290.0,
#   'air_pressure': 1012.0,
#   'humidity': 60,
#   'visibility': 13.041959953869402,
#   'predictability': 73},
#  {'id': 6034350195867648,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-17T21:29:38.838727Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.48,
#   'max_temp': 24.29,
#   'the_temp': 23.59,
#   'wind_speed': 3.6944599078262943,
#   'wind_direction': 298.3780778653654,
#   'air_pressure': 1010.5,
#   'humidity': 60,
#   'visibility': 12.146564065855404,
#   'predictability': 75},
#  {'id': 5492408034787328,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-17T18:29:41.965740Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.765,
#   'max_temp': 22.625,
#   'the_temp': 22.54,
#   'wind_speed': 3.3230619386330496,
#   'wind_direction': 309.99847470611667,
#   'air_pressure': 1013.0,
#   'humidity': 65,
#   'visibility': 12.901840750019883,
#   'predictability': 75},
#  {'id': 4828190235164672,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-17T15:29:42.055016Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.765,
#   'max_temp': 22.625,
#   'the_temp': 22.435000000000002,
#   'wind_speed': 3.3230619386330496,
#   'wind_direction': 309.99847470611667,
#   'air_pressure': 1013.0,
#   'humidity': 66,
#   'visibility': 13.476609102839417,
#   'predictability': 75},
#  {'id': 5481795036381184,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-17T12:29:40.479368Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.745000000000001,
#   'max_temp': 22.965,
#   'the_temp': 22.625,
#   'wind_speed': 3.4518928572098946,
#   'wind_direction': 311.33387178440324,
#   'air_pressure': 1013.0,
#   'humidity': 63,
#   'visibility': 13.224643084387179,
#   'predictability': 75},
#  {'id': 4808211490144256,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-17T09:29:41.267969Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.55,
#   'max_temp': 23.31,
#   'the_temp': 22.595,
#   'wind_speed': 3.738210990543228,
#   'wind_direction': 326.5287173916311,
#   'air_pressure': 1013.5,
#   'humidity': 61,
#   'visibility': 12.605446691322676,
#   'predictability': 75},
#  {'id': 4745430644555776,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-17T06:29:41.346865Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.309999999999999,
#   'max_temp': 23.145,
#   'the_temp': 23.205,
#   'wind_speed': 3.5066467224899918,
#   'wind_direction': 323.9202374139645,
#   'air_pressure': 1013.5,
#   'humidity': 59,
#   'visibility': 12.826344150163049,
#   'predictability': 71},
#  {'id': 5665936256270336,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-17T03:29:41.267475Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.265,
#   'max_temp': 23.985,
#   'the_temp': 23.2,
#   'wind_speed': 3.1301543224899917,
#   'wind_direction': 315.0,
#   'air_pressure': 1013.5,
#   'humidity': 61,
#   'visibility': 13.83047999681858,
#   'predictability': 73},
#  {'id': 6450804183531520,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-17T00:29:40.654500Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.715,
#   'max_temp': 24.325,
#   'the_temp': 22.67,
#   'wind_speed': 3.4801932177152097,
#   'wind_direction': 284.0,
#   'air_pressure': 1013.5,
#   'humidity': 62,
#   'visibility': 12.908675833134495,
#   'predictability': 75},
#  {'id': 6192726309601280,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-16T21:29:40.612885Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.715,
#   'max_temp': 24.325,
#   'the_temp': 23.034999999999997,
#   'wind_speed': 3.52493181771521,
#   'wind_direction': 296.3952340365035,
#   'air_pressure': 1012.0,
#   'humidity': 60,
#   'visibility': 13.062465203213234,
#   'predictability': 75},
#  {'id': 6717817904693248,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-16T18:29:45.292134Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.08,
#   'max_temp': 24.17,
#   'the_temp': 23.775,
#   'wind_speed': 3.629774797998356,
#   'wind_direction': 286.57783312937227,
#   'air_pressure': 1013.5,
#   'humidity': 59,
#   'visibility': 12.953103873379463,
#   'predictability': 73},
#  {'id': 6282622391025664,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-16T15:29:44.543147Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.08,
#   'max_temp': 24.17,
#   'the_temp': 23.740000000000002,
#   'wind_speed': 3.6819698313316898,
#   'wind_direction': 286.57783312937227,
#   'air_pressure': 1013.0,
#   'humidity': 60,
#   'visibility': 13.768653563190965,
#   'predictability': 71},
#  {'id': 5448740968071168,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-16T12:29:43.717590Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.055,
#   'max_temp': 23.845,
#   'the_temp': 22.86,
#   'wind_speed': 3.4731890687929163,
#   'wind_direction': 294.27095968840945,
#   'air_pressure': 1012.5,
#   'humidity': 63,
#   'visibility': 13.328722759086933,
#   'predictability': 77},
#  {'id': 4787503775088640,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-16T09:29:43.072039Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.969999999999999,
#   'max_temp': 23.875,
#   'the_temp': 22.79,
#   'wind_speed': 3.759158668792916,
#   'wind_direction': 307.8915561164231,
#   'air_pressure': 1012.5,
#   'humidity': 63,
#   'visibility': 11.975686987990137,
#   'predictability': 77},
#  {'id': 6096300569264128,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-16T06:29:43.265141Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.85,
#   'max_temp': 24.28,
#   'the_temp': 23.1,
#   'wind_speed': 3.7450742131551737,
#   'wind_direction': 297.9668165243225,
#   'air_pressure': 1012.0,
#   'humidity': 61,
#   'visibility': 12.675040264853257,
#   'predictability': 75},
#  {'id': 5919543035691008,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-16T03:29:43.055793Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.965,
#   'max_temp': 23.79,
#   'the_temp': 23.255000000000003,
#   'wind_speed': 3.5427049131551738,
#   'wind_direction': 300.74522575347123,
#   'air_pressure': 1012.0,
#   'humidity': 63,
#   'visibility': 13.897588085580212,
#   'predictability': 75},
#  {'id': 4888432553754624,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-16T00:29:44.179349Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.715,
#   'max_temp': 21.015,
#   'the_temp': 20.065,
#   'wind_speed': 3.866646553882658,
#   'wind_direction': 306.13979750243465,
#   'air_pressure': 1010.0,
#   'humidity': 76,
#   'visibility': 13.623874075399666,
#   'predictability': 75},
#  {'id': 6000994439659520,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-15T21:29:42.971159Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.715,
#   'max_temp': 21.015,
#   'the_temp': 17.1,
#   'wind_speed': 4.334780680823988,
#   'wind_direction': 289.0,
#   'air_pressure': 1002.0,
#   'humidity': 83,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 6483666857361408,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-15T18:29:46.542707Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.170000000000002,
#   'max_temp': 20.465,
#   'the_temp': 18.42,
#   'wind_speed': 4.030308796627694,
#   'wind_direction': 346.0,
#   'air_pressure': 1008.0,
#   'humidity': 78,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5982289555095552,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-15T15:29:47.339323Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.170000000000002,
#   'max_temp': 20.465,
#   'the_temp': 18.42,
#   'wind_speed': 4.030308796627694,
#   'wind_direction': 346.0,
#   'air_pressure': 1008.0,
#   'humidity': 78,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 4505435287584768,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-15T12:29:47.547152Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.3,
#   'max_temp': 23.23,
#   'the_temp': 23.21,
#   'wind_speed': 4.170117314881095,
#   'wind_direction': 327.0,
#   'air_pressure': 1008.0,
#   'humidity': 67,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5184659904266240,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-15T09:29:47.792083Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.17,
#   'max_temp': 24.744999999999997,
#   'the_temp': 23.21,
#   'wind_speed': 4.050117314881094,
#   'wind_direction': 326.5,
#   'air_pressure': 1008.0,
#   'humidity': 60,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5209980615524352,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-15T06:29:47.889727Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.61,
#   'max_temp': 25.369999999999997,
#   'the_temp': 24.37,
#   'wind_speed': 4.1930326890956815,
#   'wind_direction': 320.5,
#   'air_pressure': 1011.0,
#   'humidity': 57,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5913899448664064,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-15T03:29:46.385115Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.565,
#   'max_temp': 25.11,
#   'the_temp': 24.37,
#   'wind_speed': 3.758032689095681,
#   'wind_direction': 338.0,
#   'air_pressure': 1011.0,
#   'humidity': 57,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5978459652227072,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-07-15T00:29:46.462514Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.115,
#   'max_temp': 24.64,
#   'the_temp': 23.8,
#   'wind_speed': 3.469095084705321,
#   'wind_direction': 15.999999999999995,
#   'air_pressure': 1008.0,
#   'humidity': 50,
#   'visibility': 9.999726596675416,
#   'predictability': 70},
#  {'id': 6040788351844352,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-07-14T21:29:46.479269Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.115,
#   'max_temp': 24.64,
#   'the_temp': 23.8,
#   'wind_speed': 3.469095084705321,
#   'wind_direction': 15.999999999999995,
#   'air_pressure': 1008.0,
#   'humidity': 50,
#   'visibility': 9.999726596675416,
#   'predictability': 70},
#  {'id': 5546936000053248,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-14T18:29:50.573289Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.844999999999999,
#   'max_temp': 23.275,
#   'the_temp': 21.16,
#   'wind_speed': 4.605901733874175,
#   'wind_direction': 346.5,
#   'air_pressure': 1011.0,
#   'humidity': 64,
#   'visibility': 9.529348604151753,
#   'predictability': 77},
#  {'id': 5112107471208448,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-07-14T15:30:06.980581Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.844999999999999,
#   'max_temp': 23.275,
#   'the_temp': 21.16,
#   'wind_speed': 4.605901733874175,
#   'wind_direction': 346.5,
#   'air_pressure': 1011.0,
#   'humidity': 64,
#   'visibility': 9.529348604151753,
#   'predictability': 77},
#  {'id': 4683193112330240,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-14T12:28:49.948758Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.82,
#   'max_temp': 24.8,
#   'the_temp': 24.02,
#   'wind_speed': 4.6152223017577345,
#   'wind_direction': 356.5,
#   'air_pressure': 1011.0,
#   'humidity': 62,
#   'visibility': 9.529348604151753,
#   'predictability': 77},
#  {'id': 6527141623627776,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-14T09:28:49.746457Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.0,
#   'max_temp': 24.455,
#   'the_temp': 24.02,
#   'wind_speed': 5.250222301757734,
#   'wind_direction': 2.999999999999988,
#   'air_pressure': 1011.0,
#   'humidity': 64,
#   'visibility': 9.651758729022509,
#   'predictability': 77},
#  {'id': 4983152957194240,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-14T06:28:49.218896Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.905,
#   'max_temp': 23.29,
#   'the_temp': 22.57,
#   'wind_speed': 5.060704088125348,
#   'wind_direction': 355.0,
#   'air_pressure': 1009.0,
#   'humidity': 65,
#   'visibility': 9.651758729022509,
#   'predictability': 77},
#  {'id': 6205194331226112,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-14T03:28:49.646224Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.995,
#   'max_temp': 23.75,
#   'the_temp': 22.57,
#   'wind_speed': 5.290704088125348,
#   'wind_direction': 358.5,
#   'air_pressure': 1009.0,
#   'humidity': 63,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6482354241536000,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-14T00:28:51.376018Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.219999999999999,
#   'max_temp': 24.14,
#   'the_temp': 22.75,
#   'wind_speed': 5.296917800047721,
#   'wind_direction': 1.9999999999999993,
#   'air_pressure': 1009.0,
#   'humidity': 54,
#   'visibility': 9.999726596675416,
#   'predictability': 70},
#  {'id': 6538574960787456,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-13T21:28:51.960596Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.219999999999999,
#   'max_temp': 24.14,
#   'the_temp': 22.75,
#   'wind_speed': 5.296917800047721,
#   'wind_direction': 1.9999999999999993,
#   'air_pressure': 1009.0,
#   'humidity': 54,
#   'visibility': 9.999726596675416,
#   'predictability': 70},
#  {'id': 5667761751588864,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-13T18:28:52.857300Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.64,
#   'max_temp': 24.21,
#   'the_temp': 23.11,
#   'wind_speed': 5.230222301757735,
#   'wind_direction': 351.5,
#   'air_pressure': 1017.0,
#   'humidity': 55,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 6074970922811392,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-13T15:28:52.787511Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.64,
#   'max_temp': 24.21,
#   'the_temp': 23.11,
#   'wind_speed': 5.230222301757735,
#   'wind_direction': 351.5,
#   'air_pressure': 1017.0,
#   'humidity': 55,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 5568341815066624,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-13T12:28:52.974109Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.805,
#   'max_temp': 24.345,
#   'the_temp': 23.16,
#   'wind_speed': 5.295466276942655,
#   'wind_direction': 356.5,
#   'air_pressure': 1015.0,
#   'humidity': 56,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 5038612494155776,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'N',
#   'created': '2020-07-13T09:28:52.672721Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.049999999999999,
#   'max_temp': 24.134999999999998,
#   'the_temp': 23.16,
#   'wind_speed': 5.470466276942655,
#   'wind_direction': 9.499999999999998,
#   'air_pressure': 1015.0,
#   'humidity': 63,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6416168493514752,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-07-13T06:28:52.968890Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.37,
#   'max_temp': 23.560000000000002,
#   'the_temp': 21.89,
#   'wind_speed': 5.7842587290225085,
#   'wind_direction': 25.499999999999996,
#   'air_pressure': 1014.0,
#   'humidity': 58,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 4859397467537408,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-07-13T03:28:52.863944Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.79,
#   'max_temp': 23.51,
#   'the_temp': 21.89,
#   'wind_speed': 3.678517458045017,
#   'wind_direction': 40.0,
#   'air_pressure': 1014.0,
#   'humidity': 35,
#   'visibility': None,
#   'predictability': 68},
#  {'id': 6360345226510336,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-13T00:28:51.971253Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.06,
#   'max_temp': 21.5,
#   'the_temp': 19.97,
#   'wind_speed': 4.219110395291498,
#   'wind_direction': 284.0,
#   'air_pressure': 1004.0,
#   'humidity': 40,
#   'visibility': None,
#   'predictability': 68},
#  {'id': 5016182396551168,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-07-12T21:28:52.276977Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.06,
#   'max_temp': 21.5,
#   'the_temp': 19.97,
#   'wind_speed': 4.219110395291498,
#   'wind_direction': 284.0,
#   'air_pressure': 1004.0,
#   'humidity': 40,
#   'visibility': None,
#   'predictability': 68},
#  {'id': 5271940921032704,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-07-12T18:28:55.556794Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 17.66,
#   'max_temp': 23.27,
#   'the_temp': 18.55,
#   'wind_speed': 1.6777022190408017,
#   'wind_direction': 14.999999999999998,
#   'air_pressure': 1005.0,
#   'humidity': 82,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5120773607915520,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-07-12T15:28:55.767568Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 17.66,
#   'max_temp': 23.27,
#   'the_temp': 18.55,
#   'wind_speed': 1.6777022190408017,
#   'wind_direction': 14.999999999999998,
#   'air_pressure': 1005.0,
#   'humidity': 82,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 6677667845767168,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-12T12:28:56.353567Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 13.96,
#   'max_temp': 22.75,
#   'the_temp': 21.25,
#   'wind_speed': 2.895589755825976,
#   'wind_direction': 305.0,
#   'air_pressure': 1014.0,
#   'humidity': 42,
#   'visibility': None,
#   'predictability': 68},
#  {'id': 6138189385302016,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-12T09:28:55.458437Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 13.96,
#   'max_temp': 22.75,
#   'the_temp': 21.25,
#   'wind_speed': 2.895589755825976,
#   'wind_direction': 305.0,
#   'air_pressure': 1014.0,
#   'humidity': 42,
#   'visibility': None,
#   'predictability': 68},
#  {'id': 6017893491802112,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-12T06:28:56.068337Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.35,
#   'max_temp': 19.09,
#   'the_temp': 16.16,
#   'wind_speed': 4.026485325697924,
#   'wind_direction': 306.0,
#   'air_pressure': 1009.0,
#   'humidity': 74,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 5086167177363456,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-07-12T03:28:55.565714Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 15.35,
#   'max_temp': 19.09,
#   'the_temp': 16.16,
#   'wind_speed': 4.026485325697924,
#   'wind_direction': 306.0,
#   'air_pressure': 1009.0,
#   'humidity': 74,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 6477870966767616,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-07-12T00:28:57.379884Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.77,
#   'max_temp': 23.89,
#   'the_temp': 22.39,
#   'wind_speed': 2.8085977889127496,
#   'wind_direction': 17.000000000000004,
#   'air_pressure': 1011.0,
#   'humidity': 44,
#   'visibility': None,
#   'predictability': 68},
#  {'id': 4715301616746496,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-07-11T21:28:55.964456Z',
#   'applicable_date': '2020-07-20',
#   'min_temp': 14.77,
#   'max_temp': 23.89,
#   'the_temp': 22.39,
#   'wind_speed': 2.8085977889127496,
#   'wind_direction': 17.000000000000004,
#   'air_pressure': 1011.0,
#   'humidity': 44,
#   'visibility': None,
#   'predictability': 68}]

# %% [markdown]
# На самом деле ответ был преобразован не в словарь, а в список словарей. И каждый словарь содержит одинаковую иформацию.\
# Для нас важно то, что все словари в этом списке имеют одинаковый набор полей. А значит мы можем преобразовать этот список в датафрейм.\
# Для этого воспользуемся функцией `read_json` библиотеки **`pandas`**. Передадим ей на вход строку, полученную от сервера и выедем первые 5 строк на экран.

# %%
df = pd.read_json(response)
df.head()
# Out:
#                  id weather_state_name weather_state_abbr  \
# 0  4919777191526400         Light Rain                 lr
# 1  5843753002598400            Showers                  s
# 2  4695383806574592            Showers                  s
# 3  4806990276591616            Showers                  s
# 4  6202314589208576         Light Rain                 lr
#
#   wind_direction_compass                      created applicable_date  \
# 0                    WNW  2020-07-20T18:29:31.885101Z      2020-07-20
# 1                    WNW  2020-07-20T15:29:31.460467Z      2020-07-20
# 2                     NW  2020-07-20T12:29:32.565565Z      2020-07-20
# 3                     NW  2020-07-20T09:29:32.257786Z      2020-07-20
# 4                    NNW  2020-07-20T06:29:32.073897Z      2020-07-20
#
#    min_temp  max_temp  the_temp  wind_speed  wind_direction  air_pressure  \
# 0    16.795    24.020    23.005    2.833971      300.697175        1011.5
# 1    16.795    24.020    22.950    2.833971      300.697175        1011.5
# 2    16.725    23.920    21.940    2.741180      313.666637        1013.0
# 3    16.840    22.765    21.900    2.541970      317.329902        1013.0
# 4    15.115    21.955    20.640    2.356801      328.280489        1013.0
#
#    humidity  visibility  predictability
# 0        66   12.808946              75
# 1        66   12.808946              73
# 2        71   12.808946              73
# 3        71   12.501367              73
# 4        69   11.168215              75

# %% [markdown]
# И теперь мы можем работать как с обычным датафреймом. Например, давайте посмотрим за какой период времени доступны данные о погоде.\
# Для этого найдём минимум и максимум столбца с датой

# %%
df['created'].min()
# Out:
# '2020-07-11T21:28:55.964456Z'

# %%
df['created'].max()
# Out:
# '2020-07-20T18:29:31.885101Z'

# %% [markdown]
# Здесь мы видим, что формат даты содержит помимо YYYY-mm-dd ещё и время с точностью до микросекунд. Это наиболее полный формат записи даты и времени.\
# Итак, мы нашли данные минимум и максимум даты, похоже что нам доступны данные сразу за неделю, а не за один день. Это хорошо. Т.е. если нам нужен больший период времени, то нам понадобится делать меньше запросов к веб-серверу.
#
# Вернёмся к функции `read_json`. Кроме строки с JSON, в эту функцию можно передать адрес сервиса, возвращающего JSON.\
# Давайте попробуем: скопируем адрес сервиса и передадим его в функцию `read_json`

# %%
df = pd.read_json(url)
df.head()
# Out:
#                  id weather_state_name weather_state_abbr  \
# 0  4919777191526400         Light Rain                 lr
# 1  5843753002598400            Showers                  s
# 2  4695383806574592            Showers                  s
# 3  4806990276591616            Showers                  s
# 4  6202314589208576         Light Rain                 lr
#
#   wind_direction_compass                      created applicable_date  \
# 0                    WNW  2020-07-20T18:29:31.885101Z      2020-07-20
# 1                    WNW  2020-07-20T15:29:31.460467Z      2020-07-20
# 2                     NW  2020-07-20T12:29:32.565565Z      2020-07-20
# 3                     NW  2020-07-20T09:29:32.257786Z      2020-07-20
# 4                    NNW  2020-07-20T06:29:32.073897Z      2020-07-20
#
#    min_temp  max_temp  the_temp  wind_speed  wind_direction  air_pressure  \
# 0    16.795    24.020    23.005    2.833971      300.697175        1011.5
# 1    16.795    24.020    22.950    2.833971      300.697175        1011.5
# 2    16.725    23.920    21.940    2.741180      313.666637        1013.0
# 3    16.840    22.765    21.900    2.541970      317.329902        1013.0
# 4    15.115    21.955    20.640    2.356801      328.280489        1013.0
#
#    humidity  visibility  predictability
# 0        66   12.808946              75
# 1        66   12.808946              73
# 2        71   12.808946              73
# 3        71   12.501367              73
# 4        69   11.168215              75

# %% [markdown]
# Итак, мы убедились, что это тот же самый датафрейм. И при этом нам не понадобилось выполнять промежуточные шаги: сначала читать JSON, потом передавать преобразованную строку в **`pandas`**. Но следует обратить внимание на то, что в датафрейм можно преобразовать только список словарей, но не обычный словарь.
#
# ### Выводы
# На уроке мы узнали:
# * JSON - текстровый формат записи данных об объектах
# * JSON чаще всего используются для передачи данных между клиентом и сервером
# * Как запросить данные у веб-серверов
# * Как преобразовать в датафрейм

# %% [markdown]
# ### Практика
#
# #### Задание 1
#
# Используя сервис MetaWeather, найдите идентификатор города Париж (Paris). Для запроса используйте адрес из следующей ячейки, заменив `%city%` на имя города.

# %%
url = "https://www.metaweather.com/api/location/search/?query=%s" % ('Paris')

with req.urlopen(url) as session:
    response = session.read().decode()

data = json.loads(response)
data[0]
# Out:
# {'title': 'Paris',
#  'location_type': 'City',
#  'woeid': 615702,
#  'latt_long': '48.856930,2.341200'}

# %% [markdown]
# #### Задание 2
#
# Используя полученный идентификатор города, запросите данные о погоде в Париже за 28 мая 2020 года. Для запроса используйте адрес из следующей ячейки, заменив `%city_id%`, `%year%`, `%month%`, `%day%` на идентификатор города, год, месяц и день соответственно. JSON с данными о погоде преобразуйте к датафрейму и найдите среднюю температуру для тех данных, которые вы получили от сервиса. Актуальная температура записывается в столбце `the_temp`.

# %%
url = 'https://www.metaweather.com/api/location/%s/%s/' % (data[0]['woeid'], '2020/05/28')

with req.urlopen(url) as session:
    response = session.read().decode()

df = pd.read_json(response)
df.head()
# Out:
#                  id weather_state_name weather_state_abbr  \
# 0  6723109975490560              Clear                  c
# 1  5582221102546944              Clear                  c
# 2  4875719383449600              Clear                  c
# 3  5781794072821760              Clear                  c
# 4  5252630563520512              Clear                  c
#
#   wind_direction_compass                      created applicable_date  \
# 0                     NE  2020-05-28T21:36:04.490586Z      2020-05-28
# 1                     NE  2020-05-28T18:36:05.696646Z      2020-05-28
# 2                     NE  2020-05-28T15:36:05.294001Z      2020-05-28
# 3                     NE  2020-05-28T12:36:04.965983Z      2020-05-28
# 4                     NE  2020-05-28T09:36:04.743683Z      2020-05-28
#
#    min_temp  max_temp  the_temp  wind_speed  wind_direction  air_pressure  \
# 0    14.970    21.925    21.810    7.253747       45.331452        1028.0
# 1    13.895    24.470    24.165    7.170185       41.668908        1028.5
# 2    13.895    24.470    24.165    7.170185       41.668908        1028.5
# 3    13.865    23.555    22.340    7.230251       42.670098        1030.0
# 4    13.930    23.000    22.370    7.199636       43.334991        1030.0
#
#    humidity  visibility  predictability
# 0        43   15.078815              68
# 1        42   15.078815              68
# 2        42   15.078815              68
# 3        48   15.078815              68
# 4        47   14.516474              68

# %%
df.the_temp.mean()
# Out:
# 23.024791666666673

# %% [markdown]
# ## **18.2** *Чтение и запись файлов в формате JSON*
#
# **План урока**
# * Запись данных JSON в файлы
# * Чтение файлов в формате JSON
#
# Файлы в формате JSON  - это текстовые файлы. А значит, их можно открыть с помощью блокнота и посмотреть что в этих файлах записано.
#
# Выполним запрос к сервису погоды ещё раз, чтобы работать со свежими данными.

# %%
url = 'https://www.metaweather.com/api/location/2122265/2020/06/20/'

with req.urlopen(url) as session:
    response = session.read().decode()
    s = json.loads(response) # сохраняем ответ сервера в переменную s
s
# Out:
# [{'id': 4723897926680576,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-20T18:28:31.731018Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.674999999999997,
#   'max_temp': 25.810000000000002,
#   'the_temp': 24.695,
#   'wind_speed': 4.646417370025716,
#   'wind_direction': 40.0,
#   'air_pressure': 1014.0,
#   'humidity': 72,
#   'visibility': 14.283459595959595,
#   'predictability': 77},
#  {'id': 5424697472712704,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-20T15:28:31.713244Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.674999999999997,
#   'max_temp': 25.810000000000002,
#   'the_temp': 24.695,
#   'wind_speed': 4.646417370025716,
#   'wind_direction': 40.0,
#   'air_pressure': 1014.0,
#   'humidity': 72,
#   'visibility': 14.283459595959595,
#   'predictability': 75},
#  {'id': 5918873591218176,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-20T12:28:31.907804Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.979999999999997,
#   'max_temp': 28.18,
#   'the_temp': 27.485,
#   'wind_speed': 3.7466738551764363,
#   'wind_direction': 27.740008260428805,
#   'air_pressure': 1014.0,
#   'humidity': 64,
#   'visibility': 14.283459595959595,
#   'predictability': 75},
#  {'id': 5531583773671424,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-20T09:28:32.329702Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.985,
#   'max_temp': 28.65,
#   'the_temp': 27.439999999999998,
#   'wind_speed': 3.5764995885097695,
#   'wind_direction': 30.29213361107689,
#   'air_pressure': 1014.0,
#   'humidity': 63,
#   'visibility': 12.658573928258967,
#   'predictability': 77},
#  {'id': 6432472222924800,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-20T06:28:31.423102Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.28,
#   'max_temp': 29.665,
#   'the_temp': 29.515,
#   'wind_speed': 3.2173472281582227,
#   'wind_direction': 34.01101756444167,
#   'air_pressure': 1014.0,
#   'humidity': 56,
#   'visibility': 14.147689990455738,
#   'predictability': 75},
#  {'id': 4745472956694528,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-20T03:28:32.040278Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.18,
#   'max_temp': 29.71,
#   'the_temp': 29.485,
#   'wind_speed': 3.2598907948248894,
#   'wind_direction': 34.01101756444167,
#   'air_pressure': 1014.0,
#   'humidity': 57,
#   'visibility': 14.234681957368965,
#   'predictability': 75},
#  {'id': 5229048156389376,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'ENE',
#   'created': '2020-06-20T00:28:31.841135Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.580000000000002,
#   'max_temp': 26.020000000000003,
#   'the_temp': 25.155,
#   'wind_speed': 3.953755292823246,
#   'wind_direction': 78.00265125555421,
#   'air_pressure': 1016.5,
#   'humidity': 54,
#   'visibility': 15.600145152310507,
#   'predictability': 73},
#  {'id': 5494374559383552,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-19T21:28:32.222443Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.580000000000002,
#   'max_temp': 26.020000000000003,
#   'the_temp': 24.97,
#   'wind_speed': 3.8717345261565783,
#   'wind_direction': 56.00563223585546,
#   'air_pressure': 1015.5,
#   'humidity': 55,
#   'visibility': 11.330082319255547,
#   'predictability': 75},
#  {'id': 5551674422722560,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-19T18:28:35.245563Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.475,
#   'max_temp': 30.345,
#   'the_temp': 29.935000000000002,
#   'wind_speed': 2.8857092152496087,
#   'wind_direction': 32.36439895770562,
#   'air_pressure': 1014.0,
#   'humidity': 56,
#   'visibility': 10.477871729102043,
#   'predictability': 77},
#  {'id': 6427707896233984,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-19T15:28:36.058110Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.475,
#   'max_temp': 30.345,
#   'the_temp': 29.880000000000003,
#   'wind_speed': 2.8782527819162755,
#   'wind_direction': 32.36439895770562,
#   'air_pressure': 1014.0,
#   'humidity': 57,
#   'visibility': 10.115923009623796,
#   'predictability': 75},
#  {'id': 4831795625328640,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-19T12:28:35.208524Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.634999999999998,
#   'max_temp': 29.67,
#   'the_temp': 29.105,
#   'wind_speed': 3.145028084196294,
#   'wind_direction': 19.959271497393267,
#   'air_pressure': 1014.0,
#   'humidity': 59,
#   'visibility': 9.221148492802037,
#   'predictability': 75},
#  {'id': 5688143384674304,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-19T09:28:35.682413Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.130000000000003,
#   'max_temp': 29.78,
#   'the_temp': 29.305,
#   'wind_speed': 2.8299409508629605,
#   'wind_direction': 12.501292000778834,
#   'air_pressure': 1013.5,
#   'humidity': 56,
#   'visibility': 11.417384971764893,
#   'predictability': 77},
#  {'id': 6181351793360896,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-06-19T06:28:37.132255Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.6,
#   'max_temp': 29.67,
#   'the_temp': 29.345,
#   'wind_speed': 2.6679704451019384,
#   'wind_direction': 298.00284973908344,
#   'air_pressure': 1013.5,
#   'humidity': 55,
#   'visibility': 14.653796826533046,
#   'predictability': 75},
#  {'id': 5036734217715712,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-06-19T03:28:34.018502Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.485,
#   'max_temp': 29.655,
#   'the_temp': 29.215,
#   'wind_speed': 2.6048113784352713,
#   'wind_direction': 306.4590037110713,
#   'air_pressure': 1013.5,
#   'humidity': 56,
#   'visibility': 15.789663365942893,
#   'predictability': 75},
#  {'id': 5452899368828928,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'E',
#   'created': '2020-06-19T00:28:34.725544Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.515,
#   'max_temp': 25.98,
#   'the_temp': 25.354999999999997,
#   'wind_speed': 3.562137010260081,
#   'wind_direction': 96.81947125530712,
#   'air_pressure': 1017.0,
#   'humidity': 54,
#   'visibility': 15.588028414061878,
#   'predictability': 73},
#  {'id': 5159899686240256,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'ENE',
#   'created': '2020-06-18T21:28:35.543932Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.515,
#   'max_temp': 25.98,
#   'the_temp': 24.994999999999997,
#   'wind_speed': 3.5099419769267484,
#   'wind_direction': 70.49999999999999,
#   'air_pressure': 1016.0,
#   'humidity': 52,
#   'visibility': 14.146447248071263,
#   'predictability': 75},
#  {'id': 4776845209763840,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-18T18:28:38.835979Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.91,
#   'max_temp': 29.825,
#   'the_temp': 29.86,
#   'wind_speed': 2.9970565678066756,
#   'wind_direction': 36.43633862357382,
#   'air_pressure': 1013.5,
#   'humidity': 53,
#   'visibility': 14.329441064185158,
#   'predictability': 77},
#  {'id': 6497435415216128,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-18T15:28:39.252832Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.91,
#   'max_temp': 29.825,
#   'the_temp': 29.854999999999997,
#   'wind_speed': 2.937405101140009,
#   'wind_direction': 36.43633862357382,
#   'air_pressure': 1014.0,
#   'humidity': 54,
#   'visibility': 15.539250775471247,
#   'predictability': 75},
#  {'id': 6665698141011968,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-18T12:28:38.246837Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 19.02,
#   'max_temp': 29.515,
#   'the_temp': 29.490000000000002,
#   'wind_speed': 3.018183356130862,
#   'wind_direction': 17.860675418866176,
#   'air_pressure': 1013.5,
#   'humidity': 54,
#   'visibility': 15.007046349319971,
#   'predictability': 77},
#  {'id': 4758670049017856,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'N',
#   'created': '2020-06-18T09:28:37.143506Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.325,
#   'max_temp': 29.08,
#   'the_temp': 29.810000000000002,
#   'wind_speed': 3.415291256130862,
#   'wind_direction': 7.7130321813074225,
#   'air_pressure': 1013.5,
#   'humidity': 54,
#   'visibility': 14.166952497415096,
#   'predictability': 75},
#  {'id': 5330697818472448,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'N',
#   'created': '2020-06-18T06:28:41.015246Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.805,
#   'max_temp': 28.744999999999997,
#   'the_temp': 29.46,
#   'wind_speed': 3.716034976094276,
#   'wind_direction': 356.89960368263144,
#   'air_pressure': 1014.0,
#   'humidity': 55,
#   'visibility': 14.301790046130597,
#   'predictability': 75},
#  {'id': 5603056475439104,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'N',
#   'created': '2020-06-18T03:28:38.057461Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.985,
#   'max_temp': 28.515,
#   'the_temp': 29.310000000000002,
#   'wind_speed': 3.7203323427609427,
#   'wind_direction': 350.3671858921635,
#   'air_pressure': 1014.0,
#   'humidity': 57,
#   'visibility': 14.869723315835522,
#   'predictability': 75},
#  {'id': 4948419623780352,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'ENE',
#   'created': '2020-06-18T00:28:36.912938Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.490000000000002,
#   'max_temp': 24.97,
#   'the_temp': 25.47,
#   'wind_speed': 4.253468741806517,
#   'wind_direction': 72.03408720724613,
#   'air_pressure': 1017.0,
#   'humidity': 55,
#   'visibility': 15.391985802910998,
#   'predictability': 73},
#  {'id': 6259124322959360,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-17T21:28:36.912915Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.490000000000002,
#   'max_temp': 24.97,
#   'the_temp': 25.075,
#   'wind_speed': 4.298207341806517,
#   'wind_direction': 19.24926037309231,
#   'air_pressure': 1015.5,
#   'humidity': 53,
#   'visibility': 13.187050127256821,
#   'predictability': 75},
#  {'id': 5155953450156032,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-17T18:28:41.254676Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.665,
#   'max_temp': 24.2,
#   'the_temp': 25.990000000000002,
#   'wind_speed': 4.4654278407592995,
#   'wind_direction': 20.9051005219477,
#   'air_pressure': 1013.5,
#   'humidity': 64,
#   'visibility': 13.827373140857393,
#   'predictability': 77},
#  {'id': 6716056364122112,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-17T15:28:40.936173Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.665,
#   'max_temp': 24.2,
#   'the_temp': 25.759999999999998,
#   'wind_speed': 4.457971407425966,
#   'wind_direction': 41.0,
#   'air_pressure': 1014.0,
#   'humidity': 66,
#   'visibility': 14.77651763699992,
#   'predictability': 75},
#  {'id': 6563580998582272,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-17T12:28:41.747236Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.92,
#   'max_temp': 24.735,
#   'the_temp': 25.42,
#   'wind_speed': 4.460042644733424,
#   'wind_direction': 19.458050519610584,
#   'air_pressure': 1014.0,
#   'humidity': 67,
#   'visibility': 14.223186590312574,
#   'predictability': 77},
#  {'id': 5090661290213376,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-17T09:28:41.650873Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.885,
#   'max_temp': 25.005,
#   'the_temp': 25.515,
#   'wind_speed': 4.302853178066757,
#   'wind_direction': 12.137424219666494,
#   'air_pressure': 1013.5,
#   'humidity': 65,
#   'visibility': 12.91178268909568,
#   'predictability': 77},
#  {'id': 6297552267771904,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-17T06:28:41.511359Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.72,
#   'max_temp': 25.095,
#   'the_temp': 24.740000000000002,
#   'wind_speed': 4.159937908719743,
#   'wind_direction': 15.25851916022202,
#   'air_pressure': 1014.5,
#   'humidity': 66,
#   'visibility': 13.386820965561123,
#   'predictability': 77},
#  {'id': 6734558210818048,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-17T03:28:40.830693Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.785,
#   'max_temp': 25.64,
#   'the_temp': 24.37,
#   'wind_speed': 4.150553408719744,
#   'wind_direction': 16.839778718174696,
#   'air_pressure': 1014.5,
#   'humidity': 68,
#   'visibility': 13.449890141573212,
#   'predictability': 75},
#  {'id': 6184769849131008,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'ENE',
#   'created': '2020-06-17T00:28:41.240141Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 15.27,
#   'max_temp': 23.72,
#   'the_temp': 24.32,
#   'wind_speed': 4.071432395257032,
#   'wind_direction': 74.29887418723969,
#   'air_pressure': 1018.0,
#   'humidity': 53,
#   'visibility': 15.376140837508947,
#   'predictability': 71},
#  {'id': 4621231095545856,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-16T21:28:41.125459Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 15.27,
#   'max_temp': 23.72,
#   'the_temp': 24.155,
#   'wind_speed': 4.145996728590365,
#   'wind_direction': 18.013792429444138,
#   'air_pressure': 1016.0,
#   'humidity': 53,
#   'visibility': 12.920792571383123,
#   'predictability': 73},
#  {'id': 4906616975523840,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-06-16T18:28:45.216813Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.580000000000002,
#   'max_temp': 27.805,
#   'the_temp': 28.455,
#   'wind_speed': 2.901996462292214,
#   'wind_direction': 334.26324842843997,
#   'air_pressure': 1013.5,
#   'humidity': 58,
#   'visibility': 12.488628907182058,
#   'predictability': 75},
#  {'id': 6334230281846784,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-06-16T15:28:43.781818Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.580000000000002,
#   'max_temp': 27.805,
#   'the_temp': 28.23,
#   'wind_speed': 2.8870835956255463,
#   'wind_direction': 348.0,
#   'air_pressure': 1013.5,
#   'humidity': 62,
#   'visibility': 13.164059393144038,
#   'predictability': 75},
#  {'id': 5469815936385024,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-16T12:28:44.709223Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.09,
#   'max_temp': 27.185000000000002,
#   'the_temp': 27.505,
#   'wind_speed': 3.48152870286593,
#   'wind_direction': 14.692746261527704,
#   'air_pressure': 1013.0,
#   'humidity': 62,
#   'visibility': 14.049824027678358,
#   'predictability': 77},
#  {'id': 6602521218908160,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-16T09:28:44.255030Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.04,
#   'max_temp': 27.6,
#   'the_temp': 27.655,
#   'wind_speed': 3.6062673028659304,
#   'wind_direction': 47.75408148522005,
#   'air_pressure': 1013.5,
#   'humidity': 60,
#   'visibility': 13.103475701900898,
#   'predictability': 75},
#  {'id': 4593416820228096,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WSW',
#   'created': '2020-06-16T06:28:45.062657Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.744999999999997,
#   'max_temp': 28.73,
#   'the_temp': 28.845,
#   'wind_speed': 3.146866930992338,
#   'wind_direction': 258.6237156166499,
#   'air_pressure': 1013.5,
#   'humidity': 57,
#   'visibility': 13.865587469179989,
#   'predictability': 75},
#  {'id': 5450024727085056,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'ESE',
#   'created': '2020-06-16T03:28:44.774659Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.259999999999998,
#   'max_temp': 28.240000000000002,
#   'the_temp': 28.67,
#   'wind_speed': 3.0230923643256715,
#   'wind_direction': 119.56994692688681,
#   'air_pressure': 1013.5,
#   'humidity': 59,
#   'visibility': 15.4618900620377,
#   'predictability': 75},
#  {'id': 5928352315604992,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'E',
#   'created': '2020-06-16T00:28:43.980355Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.975,
#   'max_temp': 25.46,
#   'the_temp': 25.35,
#   'wind_speed': 3.7422256009252632,
#   'wind_direction': 80.81824283999607,
#   'air_pressure': 1017.5,
#   'humidity': 53,
#   'visibility': 15.446977153424003,
#   'predictability': 71},
#  {'id': 4971991276716032,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-15T21:28:44.375721Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.975,
#   'max_temp': 25.46,
#   'the_temp': 22.51,
#   'wind_speed': 4.304734351387895,
#   'wind_direction': 55.99999999999999,
#   'air_pressure': 1017.0,
#   'humidity': 53,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5161260654002176,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-15T18:28:46.656423Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.825000000000003,
#   'max_temp': 26.79,
#   'the_temp': 26.13,
#   'wind_speed': 4.405361290066015,
#   'wind_direction': 20.999999999999996,
#   'air_pressure': 1014.0,
#   'humidity': 65,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 4521586780536832,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-15T15:28:49.043875Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.825000000000003,
#   'max_temp': 26.79,
#   'the_temp': 26.13,
#   'wind_speed': 4.405361290066015,
#   'wind_direction': 20.999999999999996,
#   'air_pressure': 1014.0,
#   'humidity': 65,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 6514217798598656,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-15T12:28:47.739349Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.73,
#   'max_temp': 26.63,
#   'the_temp': 25.81,
#   'wind_speed': 4.414681857949574,
#   'wind_direction': 18.999999999999996,
#   'air_pressure': 1014.0,
#   'humidity': 63,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 6131690831347712,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-15T09:28:47.799683Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.08,
#   'max_temp': 26.939999999999998,
#   'the_temp': 25.81,
#   'wind_speed': 3.9996818579495743,
#   'wind_direction': 37.0,
#   'air_pressure': 1014.0,
#   'humidity': 64,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 6365394564546560,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'ESE',
#   'created': '2020-06-15T06:28:48.113908Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 19.08,
#   'max_temp': 28.08,
#   'the_temp': 27.99,
#   'wind_speed': 3.9872544341048277,
#   'wind_direction': 102.5,
#   'air_pressure': 1013.0,
#   'humidity': 60,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 4846567896907776,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'E',
#   'created': '2020-06-15T03:28:46.610867Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.72,
#   'max_temp': 27.985,
#   'the_temp': 27.99,
#   'wind_speed': 3.8672544341048276,
#   'wind_direction': 87.5,
#   'air_pressure': 1013.0,
#   'humidity': 60,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5969566821777408,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-15T00:28:47.595493Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.255000000000003,
#   'max_temp': 24.25,
#   'the_temp': 20.01,
#   'wind_speed': 4.367458243855881,
#   'wind_direction': 40.50000000000001,
#   'air_pressure': 1016.0,
#   'humidity': 55,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 4516435772571648,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-14T21:28:46.553161Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.255000000000003,
#   'max_temp': 24.25,
#   'the_temp': 20.01,
#   'wind_speed': 4.367458243855881,
#   'wind_direction': 40.50000000000001,
#   'air_pressure': 1016.0,
#   'humidity': 55,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5972475923922944,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'E',
#   'created': '2020-06-14T18:28:50.141717Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.055,
#   'max_temp': 28.91,
#   'the_temp': 29.02,
#   'wind_speed': 2.681800485166627,
#   'wind_direction': 81.5,
#   'air_pressure': 1016.0,
#   'humidity': 56,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5090135358046208,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'E',
#   'created': '2020-06-14T15:28:49.654893Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.055,
#   'max_temp': 28.91,
#   'the_temp': 29.02,
#   'wind_speed': 2.681800485166627,
#   'wind_direction': 81.5,
#   'air_pressure': 1016.0,
#   'humidity': 56,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 6036716756402176,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'N',
#   'created': '2020-06-14T12:28:49.943761Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 19.165,
#   'max_temp': 29.285,
#   'the_temp': 29.77,
#   'wind_speed': 3.104332895888014,
#   'wind_direction': 358.5,
#   'air_pressure': 1013.0,
#   'humidity': 56,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5020204834750464,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'N',
#   'created': '2020-06-14T09:28:50.244540Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.52,
#   'max_temp': 29.314999999999998,
#   'the_temp': 29.77,
#   'wind_speed': 4.264332895888014,
#   'wind_direction': 1.499999999999994,
#   'air_pressure': 1013.0,
#   'humidity': 53,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5394125559955456,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-06-14T06:28:49.239023Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.655,
#   'max_temp': 29.605,
#   'the_temp': 30.35,
#   'wind_speed': 4.040639266682574,
#   'wind_direction': 335.5,
#   'air_pressure': 1014.0,
#   'humidity': 51,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 4612416413368320,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-06-14T03:28:49.328462Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.4,
#   'max_temp': 29.635,
#   'the_temp': 30.35,
#   'wind_speed': 4.560639266682574,
#   'wind_direction': 330.5,
#   'air_pressure': 1014.0,
#   'humidity': 52,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 6523118849884160,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-14T00:28:49.642332Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.439999999999998,
#   'max_temp': 25.765,
#   'the_temp': 21.15,
#   'wind_speed': 5.610756581563668,
#   'wind_direction': 41.49999999999999,
#   'air_pressure': 1016.0,
#   'humidity': 56,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6423174356926464,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-13T21:28:49.911562Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.439999999999998,
#   'max_temp': 25.765,
#   'the_temp': 21.15,
#   'wind_speed': 5.610756581563668,
#   'wind_direction': 41.49999999999999,
#   'air_pressure': 1016.0,
#   'humidity': 56,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6683195837775872,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'S',
#   'created': '2020-06-13T18:28:52.969206Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.39,
#   'max_temp': 30.485,
#   'the_temp': 28.89,
#   'wind_speed': 3.127974031655134,
#   'wind_direction': 184.0,
#   'air_pressure': 1014.0,
#   'humidity': 53,
#   'visibility': 9.939453591028395,
#   'predictability': 77},
#  {'id': 5848773618040832,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'S',
#   'created': '2020-06-13T15:28:52.123527Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.39,
#   'max_temp': 30.485,
#   'the_temp': 28.89,
#   'wind_speed': 3.127974031655134,
#   'wind_direction': 184.0,
#   'air_pressure': 1014.0,
#   'humidity': 53,
#   'visibility': 9.939453591028395,
#   'predictability': 77},
#  {'id': 4624573922279424,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'E',
#   'created': '2020-06-13T12:28:53.538462Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 19.72,
#   'max_temp': 28.53,
#   'the_temp': 25.41,
#   'wind_speed': 3.8829400302234944,
#   'wind_direction': 84.0,
#   'air_pressure': 1017.0,
#   'humidity': 57,
#   'visibility': 9.939453591028395,
#   'predictability': 71},
#  {'id': 6263144143912960,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-06-13T09:28:53.723367Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 19.205,
#   'max_temp': 27.674999999999997,
#   'the_temp': 25.41,
#   'wind_speed': 4.017940030223495,
#   'wind_direction': 299.0,
#   'air_pressure': 1017.0,
#   'humidity': 61,
#   'visibility': 9.999726596675416,
#   'predictability': 70},
#  {'id': 5191798576119808,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'SW',
#   'created': '2020-06-13T06:28:52.730722Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.215,
#   'max_temp': 29.63,
#   'the_temp': 28.6,
#   'wind_speed': 3.8439560963970414,
#   'wind_direction': 215.0,
#   'air_pressure': 1019.0,
#   'humidity': 60,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6474605315227648,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'SW',
#   'created': '2020-06-13T03:28:53.449238Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 21.11,
#   'max_temp': 29.77,
#   'the_temp': 28.6,
#   'wind_speed': 2.4979121927940824,
#   'wind_direction': 217.0,
#   'air_pressure': 1019.0,
#   'humidity': 48,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 6203633949474816,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'ENE',
#   'created': '2020-06-13T00:28:53.575425Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.51,
#   'max_temp': 23.94,
#   'the_temp': 22.81,
#   'wind_speed': 2.491698480871709,
#   'wind_direction': 59.99999999999999,
#   'air_pressure': 1016.0,
#   'humidity': 56,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 5844236068978688,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'ENE',
#   'created': '2020-06-12T21:28:53.464421Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.51,
#   'max_temp': 23.94,
#   'the_temp': 22.81,
#   'wind_speed': 2.491698480871709,
#   'wind_direction': 59.99999999999999,
#   'air_pressure': 1016.0,
#   'humidity': 56,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 4541776079618048,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-06-12T18:28:56.051306Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 22.64,
#   'max_temp': 31.61,
#   'the_temp': 29.95,
#   'wind_speed': 1.1557504175614413,
#   'wind_direction': 347.99999999999994,
#   'air_pressure': 1017.0,
#   'humidity': 33,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 6351655031275520,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-06-12T15:28:56.323706Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 22.64,
#   'max_temp': 31.61,
#   'the_temp': 29.95,
#   'wind_speed': 1.1557504175614413,
#   'wind_direction': 347.99999999999994,
#   'air_pressure': 1017.0,
#   'humidity': 33,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 5208857850675200,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'N',
#   'created': '2020-06-12T12:28:55.936931Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.93,
#   'max_temp': 28.99,
#   'the_temp': 28.99,
#   'wind_speed': 1.5347868448262147,
#   'wind_direction': 359.0,
#   'air_pressure': 1015.0,
#   'humidity': 46,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5795333655232512,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'N',
#   'created': '2020-06-12T09:28:57.024153Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.93,
#   'max_temp': 28.99,
#   'the_temp': 28.99,
#   'wind_speed': 1.5347868448262147,
#   'wind_direction': 359.0,
#   'air_pressure': 1015.0,
#   'humidity': 46,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5677328589914112,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-12T06:28:55.914633Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 22.33,
#   'max_temp': 31.57,
#   'the_temp': 30.13,
#   'wind_speed': 1.8206175932553885,
#   'wind_direction': 13.0,
#   'air_pressure': 1016.0,
#   'humidity': 38,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5178619301199872,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-12T03:28:56.312811Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 22.33,
#   'max_temp': 31.57,
#   'the_temp': 30.13,
#   'wind_speed': 1.8206175932553885,
#   'wind_direction': 13.0,
#   'air_pressure': 1016.0,
#   'humidity': 38,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 6264973464436736,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-12T00:28:55.218831Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.9,
#   'max_temp': 28.41,
#   'the_temp': 27.14,
#   'wind_speed': 2.1499443251411754,
#   'wind_direction': 37.0,
#   'air_pressure': 1011.0,
#   'humidity': 38,
#   'visibility': None,
#   'predictability': 68},
#  {'id': 5432302651834368,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-11T21:28:56.047726Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.9,
#   'max_temp': 28.41,
#   'the_temp': 27.14,
#   'wind_speed': 2.1499443251411754,
#   'wind_direction': 37.0,
#   'air_pressure': 1011.0,
#   'humidity': 38,
#   'visibility': None,
#   'predictability': 68}]

# %% [markdown]
# Чтобы записать данные в файл, создадим объект файла при помощи функции `open` из стандартной библиотеки python.\
# Чтобы записать в файл, нам понадобится функция `dump` из библиотеки `json`.\
# Эта функция принимает два параметра:
# 1. Строка в формате JSON
# 2. Объект файла, в который нужно записать строку
# 3. Также можно добавить необязательный параметр `indent`.\
# Этот параметр нужен для того, чтобы при сохранении файл был красиво отформатирован.\
# Благодаря этому, такой файл будет легче читаться глазами.\
#
# После записи в файл, нужно закрыть объект файла. Чтобы разрешить другим процессам работать с файлом.\
# Для этого у объекта файла нужно вызвать метод `close`. Как в случае работы с веб-сервисом.

# %%
file = open('out/file.json', 'w') # открываем файл на чтение
json.dump(s, file, indent=4) # добавим отступ в 4 пробела
file.close()

# %% [markdown]
# Откроем файл и убедимся что он он записан верно. И данные в нём красиво отформатированы, т.к. мы указали параметр `indent`.
#
# Теперь проделаем тоже самое, но будем открывать файл при промощи **менеджера контекста**.

# %%
with open('out/file.json', 'w') as file:
    json.dump(s, file, indent=4)

# %% [markdown]
# ### Чтение файла JSON
#
# Теперь прочитаем файл. Для этого откроем сохранённый файл при помощи **менеджера контекста**, добавив режим работы с файлом **r** (т.е. read - на чтение)

# %%
with open('out/file.json', 'r') as file:
    s = json.load(file)

s
# Out:
# [{'id': 4723897926680576,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-20T18:28:31.731018Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.674999999999997,
#   'max_temp': 25.810000000000002,
#   'the_temp': 24.695,
#   'wind_speed': 4.646417370025716,
#   'wind_direction': 40.0,
#   'air_pressure': 1014.0,
#   'humidity': 72,
#   'visibility': 14.283459595959595,
#   'predictability': 77},
#  {'id': 5424697472712704,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-20T15:28:31.713244Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.674999999999997,
#   'max_temp': 25.810000000000002,
#   'the_temp': 24.695,
#   'wind_speed': 4.646417370025716,
#   'wind_direction': 40.0,
#   'air_pressure': 1014.0,
#   'humidity': 72,
#   'visibility': 14.283459595959595,
#   'predictability': 75},
#  {'id': 5918873591218176,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-20T12:28:31.907804Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.979999999999997,
#   'max_temp': 28.18,
#   'the_temp': 27.485,
#   'wind_speed': 3.7466738551764363,
#   'wind_direction': 27.740008260428805,
#   'air_pressure': 1014.0,
#   'humidity': 64,
#   'visibility': 14.283459595959595,
#   'predictability': 75},
#  {'id': 5531583773671424,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-20T09:28:32.329702Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.985,
#   'max_temp': 28.65,
#   'the_temp': 27.439999999999998,
#   'wind_speed': 3.5764995885097695,
#   'wind_direction': 30.29213361107689,
#   'air_pressure': 1014.0,
#   'humidity': 63,
#   'visibility': 12.658573928258967,
#   'predictability': 77},
#  {'id': 6432472222924800,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-20T06:28:31.423102Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.28,
#   'max_temp': 29.665,
#   'the_temp': 29.515,
#   'wind_speed': 3.2173472281582227,
#   'wind_direction': 34.01101756444167,
#   'air_pressure': 1014.0,
#   'humidity': 56,
#   'visibility': 14.147689990455738,
#   'predictability': 75},
#  {'id': 4745472956694528,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-20T03:28:32.040278Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.18,
#   'max_temp': 29.71,
#   'the_temp': 29.485,
#   'wind_speed': 3.2598907948248894,
#   'wind_direction': 34.01101756444167,
#   'air_pressure': 1014.0,
#   'humidity': 57,
#   'visibility': 14.234681957368965,
#   'predictability': 75},
#  {'id': 5229048156389376,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'ENE',
#   'created': '2020-06-20T00:28:31.841135Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.580000000000002,
#   'max_temp': 26.020000000000003,
#   'the_temp': 25.155,
#   'wind_speed': 3.953755292823246,
#   'wind_direction': 78.00265125555421,
#   'air_pressure': 1016.5,
#   'humidity': 54,
#   'visibility': 15.600145152310507,
#   'predictability': 73},
#  {'id': 5494374559383552,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-19T21:28:32.222443Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.580000000000002,
#   'max_temp': 26.020000000000003,
#   'the_temp': 24.97,
#   'wind_speed': 3.8717345261565783,
#   'wind_direction': 56.00563223585546,
#   'air_pressure': 1015.5,
#   'humidity': 55,
#   'visibility': 11.330082319255547,
#   'predictability': 75},
#  {'id': 5551674422722560,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-19T18:28:35.245563Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.475,
#   'max_temp': 30.345,
#   'the_temp': 29.935000000000002,
#   'wind_speed': 2.8857092152496087,
#   'wind_direction': 32.36439895770562,
#   'air_pressure': 1014.0,
#   'humidity': 56,
#   'visibility': 10.477871729102043,
#   'predictability': 77},
#  {'id': 6427707896233984,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-19T15:28:36.058110Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.475,
#   'max_temp': 30.345,
#   'the_temp': 29.880000000000003,
#   'wind_speed': 2.8782527819162755,
#   'wind_direction': 32.36439895770562,
#   'air_pressure': 1014.0,
#   'humidity': 57,
#   'visibility': 10.115923009623796,
#   'predictability': 75},
#  {'id': 4831795625328640,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-19T12:28:35.208524Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.634999999999998,
#   'max_temp': 29.67,
#   'the_temp': 29.105,
#   'wind_speed': 3.145028084196294,
#   'wind_direction': 19.959271497393267,
#   'air_pressure': 1014.0,
#   'humidity': 59,
#   'visibility': 9.221148492802037,
#   'predictability': 75},
#  {'id': 5688143384674304,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-19T09:28:35.682413Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.130000000000003,
#   'max_temp': 29.78,
#   'the_temp': 29.305,
#   'wind_speed': 2.8299409508629605,
#   'wind_direction': 12.501292000778834,
#   'air_pressure': 1013.5,
#   'humidity': 56,
#   'visibility': 11.417384971764893,
#   'predictability': 77},
#  {'id': 6181351793360896,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-06-19T06:28:37.132255Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.6,
#   'max_temp': 29.67,
#   'the_temp': 29.345,
#   'wind_speed': 2.6679704451019384,
#   'wind_direction': 298.00284973908344,
#   'air_pressure': 1013.5,
#   'humidity': 55,
#   'visibility': 14.653796826533046,
#   'predictability': 75},
#  {'id': 5036734217715712,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NW',
#   'created': '2020-06-19T03:28:34.018502Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.485,
#   'max_temp': 29.655,
#   'the_temp': 29.215,
#   'wind_speed': 2.6048113784352713,
#   'wind_direction': 306.4590037110713,
#   'air_pressure': 1013.5,
#   'humidity': 56,
#   'visibility': 15.789663365942893,
#   'predictability': 75},
#  {'id': 5452899368828928,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'E',
#   'created': '2020-06-19T00:28:34.725544Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.515,
#   'max_temp': 25.98,
#   'the_temp': 25.354999999999997,
#   'wind_speed': 3.562137010260081,
#   'wind_direction': 96.81947125530712,
#   'air_pressure': 1017.0,
#   'humidity': 54,
#   'visibility': 15.588028414061878,
#   'predictability': 73},
#  {'id': 5159899686240256,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'ENE',
#   'created': '2020-06-18T21:28:35.543932Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.515,
#   'max_temp': 25.98,
#   'the_temp': 24.994999999999997,
#   'wind_speed': 3.5099419769267484,
#   'wind_direction': 70.49999999999999,
#   'air_pressure': 1016.0,
#   'humidity': 52,
#   'visibility': 14.146447248071263,
#   'predictability': 75},
#  {'id': 4776845209763840,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-18T18:28:38.835979Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.91,
#   'max_temp': 29.825,
#   'the_temp': 29.86,
#   'wind_speed': 2.9970565678066756,
#   'wind_direction': 36.43633862357382,
#   'air_pressure': 1013.5,
#   'humidity': 53,
#   'visibility': 14.329441064185158,
#   'predictability': 77},
#  {'id': 6497435415216128,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-18T15:28:39.252832Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.91,
#   'max_temp': 29.825,
#   'the_temp': 29.854999999999997,
#   'wind_speed': 2.937405101140009,
#   'wind_direction': 36.43633862357382,
#   'air_pressure': 1014.0,
#   'humidity': 54,
#   'visibility': 15.539250775471247,
#   'predictability': 75},
#  {'id': 6665698141011968,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-18T12:28:38.246837Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 19.02,
#   'max_temp': 29.515,
#   'the_temp': 29.490000000000002,
#   'wind_speed': 3.018183356130862,
#   'wind_direction': 17.860675418866176,
#   'air_pressure': 1013.5,
#   'humidity': 54,
#   'visibility': 15.007046349319971,
#   'predictability': 77},
#  {'id': 4758670049017856,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'N',
#   'created': '2020-06-18T09:28:37.143506Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.325,
#   'max_temp': 29.08,
#   'the_temp': 29.810000000000002,
#   'wind_speed': 3.415291256130862,
#   'wind_direction': 7.7130321813074225,
#   'air_pressure': 1013.5,
#   'humidity': 54,
#   'visibility': 14.166952497415096,
#   'predictability': 75},
#  {'id': 5330697818472448,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'N',
#   'created': '2020-06-18T06:28:41.015246Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.805,
#   'max_temp': 28.744999999999997,
#   'the_temp': 29.46,
#   'wind_speed': 3.716034976094276,
#   'wind_direction': 356.89960368263144,
#   'air_pressure': 1014.0,
#   'humidity': 55,
#   'visibility': 14.301790046130597,
#   'predictability': 75},
#  {'id': 5603056475439104,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'N',
#   'created': '2020-06-18T03:28:38.057461Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.985,
#   'max_temp': 28.515,
#   'the_temp': 29.310000000000002,
#   'wind_speed': 3.7203323427609427,
#   'wind_direction': 350.3671858921635,
#   'air_pressure': 1014.0,
#   'humidity': 57,
#   'visibility': 14.869723315835522,
#   'predictability': 75},
#  {'id': 4948419623780352,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'ENE',
#   'created': '2020-06-18T00:28:36.912938Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.490000000000002,
#   'max_temp': 24.97,
#   'the_temp': 25.47,
#   'wind_speed': 4.253468741806517,
#   'wind_direction': 72.03408720724613,
#   'air_pressure': 1017.0,
#   'humidity': 55,
#   'visibility': 15.391985802910998,
#   'predictability': 73},
#  {'id': 6259124322959360,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-17T21:28:36.912915Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.490000000000002,
#   'max_temp': 24.97,
#   'the_temp': 25.075,
#   'wind_speed': 4.298207341806517,
#   'wind_direction': 19.24926037309231,
#   'air_pressure': 1015.5,
#   'humidity': 53,
#   'visibility': 13.187050127256821,
#   'predictability': 75},
#  {'id': 5155953450156032,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-17T18:28:41.254676Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.665,
#   'max_temp': 24.2,
#   'the_temp': 25.990000000000002,
#   'wind_speed': 4.4654278407592995,
#   'wind_direction': 20.9051005219477,
#   'air_pressure': 1013.5,
#   'humidity': 64,
#   'visibility': 13.827373140857393,
#   'predictability': 77},
#  {'id': 6716056364122112,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-17T15:28:40.936173Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.665,
#   'max_temp': 24.2,
#   'the_temp': 25.759999999999998,
#   'wind_speed': 4.457971407425966,
#   'wind_direction': 41.0,
#   'air_pressure': 1014.0,
#   'humidity': 66,
#   'visibility': 14.77651763699992,
#   'predictability': 75},
#  {'id': 6563580998582272,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-17T12:28:41.747236Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.92,
#   'max_temp': 24.735,
#   'the_temp': 25.42,
#   'wind_speed': 4.460042644733424,
#   'wind_direction': 19.458050519610584,
#   'air_pressure': 1014.0,
#   'humidity': 67,
#   'visibility': 14.223186590312574,
#   'predictability': 77},
#  {'id': 5090661290213376,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-17T09:28:41.650873Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.885,
#   'max_temp': 25.005,
#   'the_temp': 25.515,
#   'wind_speed': 4.302853178066757,
#   'wind_direction': 12.137424219666494,
#   'air_pressure': 1013.5,
#   'humidity': 65,
#   'visibility': 12.91178268909568,
#   'predictability': 77},
#  {'id': 6297552267771904,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-17T06:28:41.511359Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.72,
#   'max_temp': 25.095,
#   'the_temp': 24.740000000000002,
#   'wind_speed': 4.159937908719743,
#   'wind_direction': 15.25851916022202,
#   'air_pressure': 1014.5,
#   'humidity': 66,
#   'visibility': 13.386820965561123,
#   'predictability': 77},
#  {'id': 6734558210818048,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-17T03:28:40.830693Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.785,
#   'max_temp': 25.64,
#   'the_temp': 24.37,
#   'wind_speed': 4.150553408719744,
#   'wind_direction': 16.839778718174696,
#   'air_pressure': 1014.5,
#   'humidity': 68,
#   'visibility': 13.449890141573212,
#   'predictability': 75},
#  {'id': 6184769849131008,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'ENE',
#   'created': '2020-06-17T00:28:41.240141Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 15.27,
#   'max_temp': 23.72,
#   'the_temp': 24.32,
#   'wind_speed': 4.071432395257032,
#   'wind_direction': 74.29887418723969,
#   'air_pressure': 1018.0,
#   'humidity': 53,
#   'visibility': 15.376140837508947,
#   'predictability': 71},
#  {'id': 4621231095545856,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-16T21:28:41.125459Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 15.27,
#   'max_temp': 23.72,
#   'the_temp': 24.155,
#   'wind_speed': 4.145996728590365,
#   'wind_direction': 18.013792429444138,
#   'air_pressure': 1016.0,
#   'humidity': 53,
#   'visibility': 12.920792571383123,
#   'predictability': 73},
#  {'id': 4906616975523840,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-06-16T18:28:45.216813Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.580000000000002,
#   'max_temp': 27.805,
#   'the_temp': 28.455,
#   'wind_speed': 2.901996462292214,
#   'wind_direction': 334.26324842843997,
#   'air_pressure': 1013.5,
#   'humidity': 58,
#   'visibility': 12.488628907182058,
#   'predictability': 75},
#  {'id': 6334230281846784,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-06-16T15:28:43.781818Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.580000000000002,
#   'max_temp': 27.805,
#   'the_temp': 28.23,
#   'wind_speed': 2.8870835956255463,
#   'wind_direction': 348.0,
#   'air_pressure': 1013.5,
#   'humidity': 62,
#   'visibility': 13.164059393144038,
#   'predictability': 75},
#  {'id': 5469815936385024,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-16T12:28:44.709223Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.09,
#   'max_temp': 27.185000000000002,
#   'the_temp': 27.505,
#   'wind_speed': 3.48152870286593,
#   'wind_direction': 14.692746261527704,
#   'air_pressure': 1013.0,
#   'humidity': 62,
#   'visibility': 14.049824027678358,
#   'predictability': 77},
#  {'id': 6602521218908160,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-16T09:28:44.255030Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.04,
#   'max_temp': 27.6,
#   'the_temp': 27.655,
#   'wind_speed': 3.6062673028659304,
#   'wind_direction': 47.75408148522005,
#   'air_pressure': 1013.5,
#   'humidity': 60,
#   'visibility': 13.103475701900898,
#   'predictability': 75},
#  {'id': 4593416820228096,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WSW',
#   'created': '2020-06-16T06:28:45.062657Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.744999999999997,
#   'max_temp': 28.73,
#   'the_temp': 28.845,
#   'wind_speed': 3.146866930992338,
#   'wind_direction': 258.6237156166499,
#   'air_pressure': 1013.5,
#   'humidity': 57,
#   'visibility': 13.865587469179989,
#   'predictability': 75},
#  {'id': 5450024727085056,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'ESE',
#   'created': '2020-06-16T03:28:44.774659Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.259999999999998,
#   'max_temp': 28.240000000000002,
#   'the_temp': 28.67,
#   'wind_speed': 3.0230923643256715,
#   'wind_direction': 119.56994692688681,
#   'air_pressure': 1013.5,
#   'humidity': 59,
#   'visibility': 15.4618900620377,
#   'predictability': 75},
#  {'id': 5928352315604992,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'E',
#   'created': '2020-06-16T00:28:43.980355Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.975,
#   'max_temp': 25.46,
#   'the_temp': 25.35,
#   'wind_speed': 3.7422256009252632,
#   'wind_direction': 80.81824283999607,
#   'air_pressure': 1017.5,
#   'humidity': 53,
#   'visibility': 15.446977153424003,
#   'predictability': 71},
#  {'id': 4971991276716032,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-15T21:28:44.375721Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.975,
#   'max_temp': 25.46,
#   'the_temp': 22.51,
#   'wind_speed': 4.304734351387895,
#   'wind_direction': 55.99999999999999,
#   'air_pressure': 1017.0,
#   'humidity': 53,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5161260654002176,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-15T18:28:46.656423Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.825000000000003,
#   'max_temp': 26.79,
#   'the_temp': 26.13,
#   'wind_speed': 4.405361290066015,
#   'wind_direction': 20.999999999999996,
#   'air_pressure': 1014.0,
#   'humidity': 65,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 4521586780536832,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-15T15:28:49.043875Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.825000000000003,
#   'max_temp': 26.79,
#   'the_temp': 26.13,
#   'wind_speed': 4.405361290066015,
#   'wind_direction': 20.999999999999996,
#   'air_pressure': 1014.0,
#   'humidity': 65,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 6514217798598656,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-15T12:28:47.739349Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.73,
#   'max_temp': 26.63,
#   'the_temp': 25.81,
#   'wind_speed': 4.414681857949574,
#   'wind_direction': 18.999999999999996,
#   'air_pressure': 1014.0,
#   'humidity': 63,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 6131690831347712,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-15T09:28:47.799683Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.08,
#   'max_temp': 26.939999999999998,
#   'the_temp': 25.81,
#   'wind_speed': 3.9996818579495743,
#   'wind_direction': 37.0,
#   'air_pressure': 1014.0,
#   'humidity': 64,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 6365394564546560,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'ESE',
#   'created': '2020-06-15T06:28:48.113908Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 19.08,
#   'max_temp': 28.08,
#   'the_temp': 27.99,
#   'wind_speed': 3.9872544341048277,
#   'wind_direction': 102.5,
#   'air_pressure': 1013.0,
#   'humidity': 60,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 4846567896907776,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'E',
#   'created': '2020-06-15T03:28:46.610867Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.72,
#   'max_temp': 27.985,
#   'the_temp': 27.99,
#   'wind_speed': 3.8672544341048276,
#   'wind_direction': 87.5,
#   'air_pressure': 1013.0,
#   'humidity': 60,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5969566821777408,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-15T00:28:47.595493Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.255000000000003,
#   'max_temp': 24.25,
#   'the_temp': 20.01,
#   'wind_speed': 4.367458243855881,
#   'wind_direction': 40.50000000000001,
#   'air_pressure': 1016.0,
#   'humidity': 55,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 4516435772571648,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-14T21:28:46.553161Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.255000000000003,
#   'max_temp': 24.25,
#   'the_temp': 20.01,
#   'wind_speed': 4.367458243855881,
#   'wind_direction': 40.50000000000001,
#   'air_pressure': 1016.0,
#   'humidity': 55,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5972475923922944,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'E',
#   'created': '2020-06-14T18:28:50.141717Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.055,
#   'max_temp': 28.91,
#   'the_temp': 29.02,
#   'wind_speed': 2.681800485166627,
#   'wind_direction': 81.5,
#   'air_pressure': 1016.0,
#   'humidity': 56,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5090135358046208,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'E',
#   'created': '2020-06-14T15:28:49.654893Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.055,
#   'max_temp': 28.91,
#   'the_temp': 29.02,
#   'wind_speed': 2.681800485166627,
#   'wind_direction': 81.5,
#   'air_pressure': 1016.0,
#   'humidity': 56,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 6036716756402176,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'N',
#   'created': '2020-06-14T12:28:49.943761Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 19.165,
#   'max_temp': 29.285,
#   'the_temp': 29.77,
#   'wind_speed': 3.104332895888014,
#   'wind_direction': 358.5,
#   'air_pressure': 1013.0,
#   'humidity': 56,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5020204834750464,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'N',
#   'created': '2020-06-14T09:28:50.244540Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.52,
#   'max_temp': 29.314999999999998,
#   'the_temp': 29.77,
#   'wind_speed': 4.264332895888014,
#   'wind_direction': 1.499999999999994,
#   'air_pressure': 1013.0,
#   'humidity': 53,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5394125559955456,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-06-14T06:28:49.239023Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.655,
#   'max_temp': 29.605,
#   'the_temp': 30.35,
#   'wind_speed': 4.040639266682574,
#   'wind_direction': 335.5,
#   'air_pressure': 1014.0,
#   'humidity': 51,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 4612416413368320,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-06-14T03:28:49.328462Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 18.4,
#   'max_temp': 29.635,
#   'the_temp': 30.35,
#   'wind_speed': 4.560639266682574,
#   'wind_direction': 330.5,
#   'air_pressure': 1014.0,
#   'humidity': 52,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 6523118849884160,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-14T00:28:49.642332Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.439999999999998,
#   'max_temp': 25.765,
#   'the_temp': 21.15,
#   'wind_speed': 5.610756581563668,
#   'wind_direction': 41.49999999999999,
#   'air_pressure': 1016.0,
#   'humidity': 56,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6423174356926464,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-13T21:28:49.911562Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 16.439999999999998,
#   'max_temp': 25.765,
#   'the_temp': 21.15,
#   'wind_speed': 5.610756581563668,
#   'wind_direction': 41.49999999999999,
#   'air_pressure': 1016.0,
#   'humidity': 56,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6683195837775872,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'S',
#   'created': '2020-06-13T18:28:52.969206Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.39,
#   'max_temp': 30.485,
#   'the_temp': 28.89,
#   'wind_speed': 3.127974031655134,
#   'wind_direction': 184.0,
#   'air_pressure': 1014.0,
#   'humidity': 53,
#   'visibility': 9.939453591028395,
#   'predictability': 77},
#  {'id': 5848773618040832,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'S',
#   'created': '2020-06-13T15:28:52.123527Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.39,
#   'max_temp': 30.485,
#   'the_temp': 28.89,
#   'wind_speed': 3.127974031655134,
#   'wind_direction': 184.0,
#   'air_pressure': 1014.0,
#   'humidity': 53,
#   'visibility': 9.939453591028395,
#   'predictability': 77},
#  {'id': 4624573922279424,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'E',
#   'created': '2020-06-13T12:28:53.538462Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 19.72,
#   'max_temp': 28.53,
#   'the_temp': 25.41,
#   'wind_speed': 3.8829400302234944,
#   'wind_direction': 84.0,
#   'air_pressure': 1017.0,
#   'humidity': 57,
#   'visibility': 9.939453591028395,
#   'predictability': 71},
#  {'id': 6263144143912960,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-06-13T09:28:53.723367Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 19.205,
#   'max_temp': 27.674999999999997,
#   'the_temp': 25.41,
#   'wind_speed': 4.017940030223495,
#   'wind_direction': 299.0,
#   'air_pressure': 1017.0,
#   'humidity': 61,
#   'visibility': 9.999726596675416,
#   'predictability': 70},
#  {'id': 5191798576119808,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'SW',
#   'created': '2020-06-13T06:28:52.730722Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.215,
#   'max_temp': 29.63,
#   'the_temp': 28.6,
#   'wind_speed': 3.8439560963970414,
#   'wind_direction': 215.0,
#   'air_pressure': 1019.0,
#   'humidity': 60,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6474605315227648,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'SW',
#   'created': '2020-06-13T03:28:53.449238Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 21.11,
#   'max_temp': 29.77,
#   'the_temp': 28.6,
#   'wind_speed': 2.4979121927940824,
#   'wind_direction': 217.0,
#   'air_pressure': 1019.0,
#   'humidity': 48,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 6203633949474816,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'ENE',
#   'created': '2020-06-13T00:28:53.575425Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.51,
#   'max_temp': 23.94,
#   'the_temp': 22.81,
#   'wind_speed': 2.491698480871709,
#   'wind_direction': 59.99999999999999,
#   'air_pressure': 1016.0,
#   'humidity': 56,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 5844236068978688,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'ENE',
#   'created': '2020-06-12T21:28:53.464421Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 17.51,
#   'max_temp': 23.94,
#   'the_temp': 22.81,
#   'wind_speed': 2.491698480871709,
#   'wind_direction': 59.99999999999999,
#   'air_pressure': 1016.0,
#   'humidity': 56,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 4541776079618048,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-06-12T18:28:56.051306Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 22.64,
#   'max_temp': 31.61,
#   'the_temp': 29.95,
#   'wind_speed': 1.1557504175614413,
#   'wind_direction': 347.99999999999994,
#   'air_pressure': 1017.0,
#   'humidity': 33,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 6351655031275520,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-06-12T15:28:56.323706Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 22.64,
#   'max_temp': 31.61,
#   'the_temp': 29.95,
#   'wind_speed': 1.1557504175614413,
#   'wind_direction': 347.99999999999994,
#   'air_pressure': 1017.0,
#   'humidity': 33,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 5208857850675200,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'N',
#   'created': '2020-06-12T12:28:55.936931Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.93,
#   'max_temp': 28.99,
#   'the_temp': 28.99,
#   'wind_speed': 1.5347868448262147,
#   'wind_direction': 359.0,
#   'air_pressure': 1015.0,
#   'humidity': 46,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5795333655232512,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'N',
#   'created': '2020-06-12T09:28:57.024153Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.93,
#   'max_temp': 28.99,
#   'the_temp': 28.99,
#   'wind_speed': 1.5347868448262147,
#   'wind_direction': 359.0,
#   'air_pressure': 1015.0,
#   'humidity': 46,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5677328589914112,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-12T06:28:55.914633Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 22.33,
#   'max_temp': 31.57,
#   'the_temp': 30.13,
#   'wind_speed': 1.8206175932553885,
#   'wind_direction': 13.0,
#   'air_pressure': 1016.0,
#   'humidity': 38,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5178619301199872,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-06-12T03:28:56.312811Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 22.33,
#   'max_temp': 31.57,
#   'the_temp': 30.13,
#   'wind_speed': 1.8206175932553885,
#   'wind_direction': 13.0,
#   'air_pressure': 1016.0,
#   'humidity': 38,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 6264973464436736,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-12T00:28:55.218831Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.9,
#   'max_temp': 28.41,
#   'the_temp': 27.14,
#   'wind_speed': 2.1499443251411754,
#   'wind_direction': 37.0,
#   'air_pressure': 1011.0,
#   'humidity': 38,
#   'visibility': None,
#   'predictability': 68},
#  {'id': 5432302651834368,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NE',
#   'created': '2020-06-11T21:28:56.047726Z',
#   'applicable_date': '2020-06-20',
#   'min_temp': 20.9,
#   'max_temp': 28.41,
#   'the_temp': 27.14,
#   'wind_speed': 2.1499443251411754,
#   'wind_direction': 37.0,
#   'air_pressure': 1011.0,
#   'humidity': 38,
#   'visibility': None,
#   'predictability': 68}]

# %% [markdown]
# Как и в случае с веб-сервисами, если мы работаем в JSON ввиде списка словарей, мы можем загрузить его в **`pandas`** `DataFrame`.
# Причём, мы можем загрузить как список словарей,

# %%
with open('out/file.json', 'r') as file:
    s = file.read()
    
df = pd.read_json(s)
df.head()
# Out:
#                  id weather_state_name weather_state_abbr  \
# 0  4723897926680576         Heavy Rain                 hr
# 1  5424697472712704         Light Rain                 lr
# 2  5918873591218176         Light Rain                 lr
# 3  5531583773671424         Heavy Rain                 hr
# 4  6432472222924800         Light Rain                 lr
#
#   wind_direction_compass                      created applicable_date  \
# 0                     NE  2020-06-20T18:28:31.731018Z      2020-06-20
# 1                     NE  2020-06-20T15:28:31.713244Z      2020-06-20
# 2                    NNE  2020-06-20T12:28:31.907804Z      2020-06-20
# 3                    NNE  2020-06-20T09:28:32.329702Z      2020-06-20
# 4                     NE  2020-06-20T06:28:31.423102Z      2020-06-20
#
#    min_temp  max_temp  the_temp  wind_speed  wind_direction  air_pressure  \
# 0    18.675    25.810    24.695    4.646417       40.000000        1014.0
# 1    18.675    25.810    24.695    4.646417       40.000000        1014.0
# 2    18.980    28.180    27.485    3.746674       27.740008        1014.0
# 3    18.985    28.650    27.440    3.576500       30.292134        1014.0
# 4    18.280    29.665    29.515    3.217347       34.011018        1014.0
#
#    humidity  visibility  predictability
# 0        72   14.283460              77
# 1        72   14.283460              75
# 2        64   14.283460              75
# 3        63   12.658574              77
# 4        56   14.147690              75

# %% [markdown]
# так и пропустив этот шаг, загрузить сам файл

# %%
df = pd.read_json('out/file.json')
df.head()
# Out:
#                  id weather_state_name weather_state_abbr  \
# 0  4723897926680576         Heavy Rain                 hr
# 1  5424697472712704         Light Rain                 lr
# 2  5918873591218176         Light Rain                 lr
# 3  5531583773671424         Heavy Rain                 hr
# 4  6432472222924800         Light Rain                 lr
#
#   wind_direction_compass                      created applicable_date  \
# 0                     NE  2020-06-20T18:28:31.731018Z      2020-06-20
# 1                     NE  2020-06-20T15:28:31.713244Z      2020-06-20
# 2                    NNE  2020-06-20T12:28:31.907804Z      2020-06-20
# 3                    NNE  2020-06-20T09:28:32.329702Z      2020-06-20
# 4                     NE  2020-06-20T06:28:31.423102Z      2020-06-20
#
#    min_temp  max_temp  the_temp  wind_speed  wind_direction  air_pressure  \
# 0    18.675    25.810    24.695    4.646417       40.000000        1014.0
# 1    18.675    25.810    24.695    4.646417       40.000000        1014.0
# 2    18.980    28.180    27.485    3.746674       27.740008        1014.0
# 3    18.985    28.650    27.440    3.576500       30.292134        1014.0
# 4    18.280    29.665    29.515    3.217347       34.011018        1014.0
#
#    humidity  visibility  predictability
# 0        72   14.283460              77
# 1        72   14.283460              75
# 2        64   14.283460              75
# 3        63   12.658574              77
# 4        56   14.147690              75

# %% [markdown]
# ### Итоги
#
# Итак, на этом уроке мы узнали:
# * Как сохранять данные в файле JSON с удобным форматированием
# * Как читать данные из файлов
# * Как преобразовать данные из файла JSON в датафрейм **`pandas`**

# %% [markdown]
# ### Практика
#
# #### Задание 1
#
# Используя сервис MetaWeather, найдите идентификатор Москвы (Moscow). Для запроса используйте адрес из следующей ячейки, заменив `%city%` на имя города.

# %%
url = "https://www.metaweather.com/api/location/search/?query=%s" % 'moscow'

with req.urlopen(url) as session:
    response = session.read().decode()
response
data = json.loads(response)
data[0]
# Out:
# {'title': 'Moscow',
#  'location_type': 'City',
#  'woeid': 2122265,
#  'latt_long': '55.756950,37.614971'}

# %% [markdown]
# #### Задание 2
#
# Используя полученный идентификатор города, запросите данные о погоде в Москве за 28 апреля 2020 года. Для запроса используйте адрес из следующей ячейки, заменив `%city_id%`, `%year%`, `%month%`, `%day%` на идентификатор города, год, месяц и день соответственно.

# %%
url = 'https://www.metaweather.com/api/location/%s/%s/' % (data[0]['woeid'], '2020/04/28')

with req.urlopen(url) as session:
    response = session.read().decode()
    s = json.loads(response)
    
s
# Out:
# [{'id': 4520607007899648,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-28T18:27:32.227221Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.67,
#   'max_temp': 10.915,
#   'the_temp': 9.965,
#   'wind_speed': 4.5501686624777955,
#   'wind_direction': 297.50133470847635,
#   'air_pressure': 1009.0,
#   'humidity': 39,
#   'visibility': 12.064543068480077,
#   'predictability': 73},
#  {'id': 5728158202462208,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-28T15:27:32.320780Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.67,
#   'max_temp': 10.915,
#   'the_temp': 9.92,
#   'wind_speed': 4.5501686624777955,
#   'wind_direction': 297.50133470847635,
#   'air_pressure': 1009.0,
#   'humidity': 39,
#   'visibility': 12.064543068480077,
#   'predictability': 73},
#  {'id': 5480870762774528,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-28T12:27:32.389465Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.3049999999999997,
#   'max_temp': 10.225,
#   'the_temp': 8.145,
#   'wind_speed': 4.519928933365148,
#   'wind_direction': 308.33499428378383,
#   'air_pressure': 1009.5,
#   'humidity': 51,
#   'visibility': 12.064543068480077,
#   'predictability': 73},
#  {'id': 5972593918083072,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-28T09:27:32.493205Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.195,
#   'max_temp': 9.915,
#   'the_temp': 8.025,
#   'wind_speed': 4.555980100031815,
#   'wind_direction': 308.6673835118722,
#   'air_pressure': 1009.5,
#   'humidity': 51,
#   'visibility': 10.53690199236459,
#   'predictability': 73},
#  {'id': 5468569036914688,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-28T06:27:31.423059Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.425,
#   'max_temp': 10.260000000000002,
#   'the_temp': 8.765,
#   'wind_speed': 4.571307277080517,
#   'wind_direction': 308.6673835118722,
#   'air_pressure': 1009.5,
#   'humidity': 47,
#   'visibility': 12.849024198679711,
#   'predictability': 73},
#  {'id': 5212616366489600,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-28T03:27:31.446036Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.26,
#   'max_temp': 10.635000000000002,
#   'the_temp': 8.75,
#   'wind_speed': 4.755430377080516,
#   'wind_direction': 307.6709904229787,
#   'air_pressure': 1009.5,
#   'humidity': 47,
#   'visibility': 13.045998866618945,
#   'predictability': 73},
#  {'id': 4888443760934912,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-28T00:27:32.632727Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.8449999999999998,
#   'max_temp': 12.600000000000001,
#   'the_temp': 12.435,
#   'wind_speed': 5.2744841032370955,
#   'wind_direction': 311.2624574246146,
#   'air_pressure': 1000.0,
#   'humidity': 37,
#   'visibility': 15.173573828839576,
#   'predictability': 73},
#  {'id': 5844479674155008,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-27T21:27:31.816560Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.8449999999999998,
#   'max_temp': 12.600000000000001,
#   'the_temp': 11.585,
#   'wind_speed': 5.848629469903762,
#   'wind_direction': 292.88373023762034,
#   'air_pressure': 1003.0,
#   'humidity': 46,
#   'visibility': 10.872131750576632,
#   'predictability': 73},
#  {'id': 4722492750954496,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-27T18:27:34.511103Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.3250000000000002,
#   'max_temp': 10.8,
#   'the_temp': 9.23,
#   'wind_speed': 4.374458585675654,
#   'wind_direction': 307.34963261827176,
#   'air_pressure': 1009.0,
#   'humidity': 47,
#   'visibility': 13.100368845939713,
#   'predictability': 73},
#  {'id': 6043165666574336,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-27T15:27:34.462190Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.3250000000000002,
#   'max_temp': 10.8,
#   'the_temp': 9.225000000000001,
#   'wind_speed': 4.404284319008988,
#   'wind_direction': 307.34963261827176,
#   'air_pressure': 1008.5,
#   'humidity': 48,
#   'visibility': 13.528804282987352,
#   'predictability': 73},
#  {'id': 5011162066321408,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-27T12:27:34.693266Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 0.71,
#   'max_temp': 10.66,
#   'the_temp': 9.265,
#   'wind_speed': 4.463107479514303,
#   'wind_direction': 308.02150160064934,
#   'air_pressure': 1009.0,
#   'humidity': 47,
#   'visibility': 13.008716595084703,
#   'predictability': 73},
#  {'id': 5429401602752512,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-27T09:27:35.595486Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 0.89,
#   'max_temp': 10.825,
#   'the_temp': 9.344999999999999,
#   'wind_speed': 4.524861279514304,
#   'wind_direction': 310.0061151618099,
#   'air_pressure': 1009.0,
#   'humidity': 46,
#   'visibility': 11.97040533285612,
#   'predictability': 73},
#  {'id': 5102355563413504,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-27T06:27:34.409498Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 0.8500000000000001,
#   'max_temp': 10.965,
#   'the_temp': 9.22,
#   'wind_speed': 4.55965800335905,
#   'wind_direction': 310.0061151618099,
#   'air_pressure': 1009.5,
#   'humidity': 46,
#   'visibility': 12.825101407778572,
#   'predictability': 71},
#  {'id': 5725551492857856,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-27T03:27:34.619624Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.0150000000000001,
#   'max_temp': 11.030000000000001,
#   'the_temp': 9.17,
#   'wind_speed': 4.724570870025716,
#   'wind_direction': 301.82355249485084,
#   'air_pressure': 1009.5,
#   'humidity': 47,
#   'visibility': 13.320644933587847,
#   'predictability': 71},
#  {'id': 6241938028101632,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-27T00:27:34.530307Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.745,
#   'max_temp': 12.2,
#   'the_temp': 10.52,
#   'wind_speed': 4.747770154068241,
#   'wind_direction': 298.04209422388783,
#   'air_pressure': 1000.5,
#   'humidity': 51,
#   'visibility': 14.89084993637159,
#   'predictability': 73},
#  {'id': 6353475308879872,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-26T21:27:34.739365Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.745,
#   'max_temp': 12.2,
#   'the_temp': 10.125,
#   'wind_speed': 5.224981887401575,
#   'wind_direction': 290.7808478210698,
#   'air_pressure': 1003.5,
#   'humidity': 56,
#   'visibility': 10.639738924679868,
#   'predictability': 73},
#  {'id': 5481074538840064,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-26T18:27:37.523136Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.8050000000000002,
#   'max_temp': 11.1,
#   'the_temp': 9.434999999999999,
#   'wind_speed': 5.189363735398605,
#   'wind_direction': 309.9989829823174,
#   'air_pressure': 1009.0,
#   'humidity': 47,
#   'visibility': 12.717914877117632,
#   'predictability': 73},
#  {'id': 5909991951171584,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-26T15:27:37.218842Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.8050000000000002,
#   'max_temp': 11.1,
#   'the_temp': 9.434999999999999,
#   'wind_speed': 5.2117330353986056,
#   'wind_direction': 309.9989829823174,
#   'air_pressure': 1009.0,
#   'humidity': 47,
#   'visibility': 13.315052592857711,
#   'predictability': 73},
#  {'id': 5689896956067840,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-26T12:27:37.800754Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.7349999999999999,
#   'max_temp': 11.205,
#   'the_temp': 9.465,
#   'wind_speed': 5.2009626433468545,
#   'wind_direction': 312.002747204715,
#   'air_pressure': 1009.5,
#   'humidity': 47,
#   'visibility': 12.117670305416368,
#   'predictability': 70},
#  {'id': 5056103127711744,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-26T09:27:38.809776Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.7149999999999999,
#   'max_temp': 11.16,
#   'the_temp': 9.28,
#   'wind_speed': 4.984644510013521,
#   'wind_direction': 313.0008130560872,
#   'air_pressure': 1010.0,
#   'humidity': 51,
#   'visibility': 9.706750079535514,
#   'predictability': 70},
#  {'id': 6345560019697664,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-26T06:27:37.417696Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.795,
#   'max_temp': 10.969999999999999,
#   'the_temp': 9.309999999999999,
#   'wind_speed': 4.98381588924945,
#   'wind_direction': 315.0,
#   'air_pressure': 1010.0,
#   'humidity': 47,
#   'visibility': 13.75342996898115,
#   'predictability': 73},
#  {'id': 5520572165390336,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-26T03:27:38.230928Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.745,
#   'max_temp': 10.95,
#   'the_temp': 9.205,
#   'wind_speed': 5.086974955916117,
#   'wind_direction': 317.6663655959727,
#   'air_pressure': 1009.5,
#   'humidity': 47,
#   'visibility': 14.929064264694185,
#   'predictability': 73},
#  {'id': 6085597175218176,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NNW',
#   'created': '2020-04-26T00:27:37.693172Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.425,
#   'max_temp': 9.765,
#   'the_temp': 7.755000000000001,
#   'wind_speed': 4.090296863925342,
#   'wind_direction': 330.86725894359245,
#   'air_pressure': 1005.0,
#   'humidity': 58,
#   'visibility': 13.767721506402609,
#   'predictability': 73},
#  {'id': 4707287694311424,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-25T21:27:38.712171Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.425,
#   'max_temp': 9.765,
#   'the_temp': 7.404999999999999,
#   'wind_speed': 4.560052163925342,
#   'wind_direction': 323.2935424263512,
#   'air_pressure': 1007.5,
#   'humidity': 61,
#   'visibility': 12.833489918873777,
#   'predictability': 73},
#  {'id': 5386597774131200,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-25T18:27:40.705815Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.305,
#   'max_temp': 10.19,
#   'the_temp': 8.89,
#   'wind_speed': 5.370316047320979,
#   'wind_direction': 318.6661282155967,
#   'air_pressure': 1009.0,
#   'humidity': 48,
#   'visibility': 12.383617175693947,
#   'predictability': 71},
#  {'id': 6023018310533120,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-25T15:27:41.716182Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.305,
#   'max_temp': 10.19,
#   'the_temp': 8.91,
#   'wind_speed': 5.415054647320979,
#   'wind_direction': 318.6661282155967,
#   'air_pressure': 1008.5,
#   'humidity': 50,
#   'visibility': 13.665816630875685,
#   'predictability': 71},
#  {'id': 4880358568886272,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-25T12:27:40.193497Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.385,
#   'max_temp': 10.29,
#   'the_temp': 9.155000000000001,
#   'wind_speed': 5.559626948460988,
#   'wind_direction': 319.99643554570355,
#   'air_pressure': 1008.0,
#   'humidity': 49,
#   'visibility': 12.785644337071503,
#   'predictability': 70},
#  {'id': 6627355910995968,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-25T09:27:40.708779Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.395,
#   'max_temp': 11.100000000000001,
#   'the_temp': 9.0,
#   'wind_speed': 4.411555015127655,
#   'wind_direction': 323.6745232343287,
#   'air_pressure': 1008.0,
#   'humidity': 48,
#   'visibility': 12.244430028632785,
#   'predictability': 70},
#  {'id': 5603415172317184,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-25T06:27:40.410376Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.75,
#   'max_temp': 11.375,
#   'the_temp': 9.2,
#   'wind_speed': 3.6969782489222935,
#   'wind_direction': 322.3349942837838,
#   'air_pressure': 1009.5,
#   'humidity': 48,
#   'visibility': 11.768770380975106,
#   'predictability': 71},
#  {'id': 6349476761436160,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-25T03:27:40.433114Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.02,
#   'max_temp': 11.504999999999999,
#   'the_temp': 9.205,
#   'wind_speed': 4.0752244489222935,
#   'wind_direction': 321.0024421460581,
#   'air_pressure': 1010.0,
#   'humidity': 49,
#   'visibility': 13.349849379623002,
#   'predictability': 71},
#  {'id': 4563868535750656,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-25T00:27:41.036470Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.3449999999999998,
#   'max_temp': 13.825,
#   'the_temp': 12.14,
#   'wind_speed': 4.635702711492882,
#   'wind_direction': 294.40350450294295,
#   'air_pressure': 1007.0,
#   'humidity': 46,
#   'visibility': 13.470706076513164,
#   'predictability': 73},
#  {'id': 5227287303684096,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-24T21:27:39.897827Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.3449999999999998,
#   'max_temp': 13.825,
#   'the_temp': 12.155000000000001,
#   'wind_speed': 5.015980811492882,
#   'wind_direction': 294.40350450294295,
#   'air_pressure': 1008.5,
#   'humidity': 49,
#   'visibility': 11.535445498289986,
#   'predictability': 73},
#  {'id': 5456787337641984,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-24T18:27:43.595633Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.005,
#   'max_temp': 11.04,
#   'the_temp': 9.54,
#   'wind_speed': 4.614086924123121,
#   'wind_direction': 317.29157811967093,
#   'air_pressure': 1009.0,
#   'humidity': 49,
#   'visibility': 11.869743199713671,
#   'predictability': 73},
#  {'id': 5800593429889024,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-24T15:27:42.924522Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.005,
#   'max_temp': 11.04,
#   'the_temp': 9.504999999999999,
#   'wind_speed': 4.621543357456455,
#   'wind_direction': 324.6503690081608,
#   'air_pressure': 1009.0,
#   'humidity': 51,
#   'visibility': 13.088873478883322,
#   'predictability': 73},
#  {'id': 6473013509750784,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-24T12:27:43.599229Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.6,
#   'max_temp': 10.82,
#   'the_temp': 9.225,
#   'wind_speed': 4.334884093130783,
#   'wind_direction': 323.9759968906734,
#   'air_pressure': 1008.5,
#   'humidity': 50,
#   'visibility': 12.689021116678596,
#   'predictability': 71},
#  {'id': 5767946779492352,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-24T09:27:44.727634Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.4,
#   'max_temp': 11.844999999999999,
#   'the_temp': 9.21,
#   'wind_speed': 4.02979695979745,
#   'wind_direction': 304.881289290963,
#   'air_pressure': 1009.0,
#   'humidity': 48,
#   'visibility': 11.603174958243855,
#   'predictability': 71},
#  {'id': 5835349378990080,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-24T06:27:43.555093Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.905,
#   'max_temp': 12.67,
#   'the_temp': 9.74,
#   'wind_speed': 4.0119844447944,
#   'wind_direction': 288.84468559373204,
#   'air_pressure': 1009.5,
#   'humidity': 47,
#   'visibility': 11.976619044778493,
#   'predictability': 71},
#  {'id': 6735633311596544,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-24T03:27:44.303546Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.85,
#   'max_temp': 12.61,
#   'the_temp': 9.565000000000001,
#   'wind_speed': 3.7627742114610676,
#   'wind_direction': 303.3167434401916,
#   'air_pressure': 1009.5,
#   'humidity': 49,
#   'visibility': 13.109068042631035,
#   'predictability': 71},
#  {'id': 4598092177342464,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-24T00:27:43.733175Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.715,
#   'max_temp': 13.07,
#   'the_temp': 8.955,
#   'wind_speed': 4.150096426896259,
#   'wind_direction': 291.4155746148685,
#   'air_pressure': 1005.0,
#   'humidity': 55,
#   'visibility': 13.350470750815239,
#   'predictability': 73},
#  {'id': 6154505781510144,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-23T21:27:43.327709Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.715,
#   'max_temp': 13.07,
#   'the_temp': 7.74,
#   'wind_speed': 4.558631790344389,
#   'wind_direction': 265.5,
#   'air_pressure': 1005.0,
#   'humidity': 65,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5503780722311168,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-23T18:27:47.671974Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.9749999999999999,
#   'max_temp': 11.68,
#   'the_temp': 9.53,
#   'wind_speed': 2.9891352501391872,
#   'wind_direction': 282.0,
#   'air_pressure': 1011.0,
#   'humidity': 53,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 5311494768033792,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-23T15:27:48.571545Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.9749999999999999,
#   'max_temp': 11.68,
#   'the_temp': 9.53,
#   'wind_speed': 2.9891352501391872,
#   'wind_direction': 282.0,
#   'air_pressure': 1011.0,
#   'humidity': 53,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 4823482380582912,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'WSW',
#   'created': '2020-04-23T12:27:46.721449Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.9749999999999999,
#   'max_temp': 11.56,
#   'the_temp': 10.64,
#   'wind_speed': 3.250111150878867,
#   'wind_direction': 255.5,
#   'air_pressure': 1004.0,
#   'humidity': 51,
#   'visibility': 9.999726596675416,
#   'predictability': 75},
#  {'id': 5516129525039104,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-23T09:27:46.328368Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.9749999999999996,
#   'max_temp': 11.815000000000001,
#   'the_temp': 10.64,
#   'wind_speed': 3.705111150878867,
#   'wind_direction': 275.0,
#   'air_pressure': 1004.0,
#   'humidity': 50,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5766464948666368,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WNW',
#   'created': '2020-04-23T06:27:46.480384Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.01,
#   'max_temp': 12.01,
#   'the_temp': 10.06,
#   'wind_speed': 3.910163644317188,
#   'wind_direction': 282.5,
#   'air_pressure': 1005.0,
#   'humidity': 52,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5554822784745472,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-23T03:27:46.413528Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.13,
#   'max_temp': 12.469999999999999,
#   'the_temp': 10.06,
#   'wind_speed': 3.6701636443171877,
#   'wind_direction': 264.0,
#   'air_pressure': 1005.0,
#   'humidity': 51,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 4619790352121856,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2020-04-23T00:27:47.933745Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.88,
#   'max_temp': 12.34,
#   'the_temp': 10.14,
#   'wind_speed': 4.701639823431162,
#   'wind_direction': 251.5,
#   'air_pressure': 1001.0,
#   'humidity': 68,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5012406533095424,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'WSW',
#   'created': '2020-04-22T21:27:47.913412Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.88,
#   'max_temp': 12.34,
#   'the_temp': 10.14,
#   'wind_speed': 4.701639823431162,
#   'wind_direction': 251.5,
#   'air_pressure': 1001.0,
#   'humidity': 68,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6098047698206720,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-22T18:27:50.338686Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.025,
#   'max_temp': 14.559999999999999,
#   'the_temp': 12.59,
#   'wind_speed': 2.3005929372464804,
#   'wind_direction': 311.5,
#   'air_pressure': 1012.0,
#   'humidity': 46,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 5538383193440256,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NW',
#   'created': '2020-04-22T15:27:50.115038Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.025,
#   'max_temp': 14.559999999999999,
#   'the_temp': 12.59,
#   'wind_speed': 2.3005929372464804,
#   'wind_direction': 311.5,
#   'air_pressure': 1012.0,
#   'humidity': 46,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 6316427323637760,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-22T12:27:49.195811Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.01,
#   'max_temp': 14.26,
#   'the_temp': 12.75,
#   'wind_speed': 2.943712121212121,
#   'wind_direction': 275.0,
#   'air_pressure': 1009.0,
#   'humidity': 46,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 6714499220373504,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'SW',
#   'created': '2020-04-22T09:27:51.222209Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.64,
#   'max_temp': 14.48,
#   'the_temp': 12.75,
#   'wind_speed': 4.673712121212121,
#   'wind_direction': 223.5,
#   'air_pressure': 1009.0,
#   'humidity': 47,
#   'visibility': 9.999726596675416,
#   'predictability': 71},
#  {'id': 4745102733869056,
#   'weather_state_name': 'Light Rain',
#   'weather_state_abbr': 'lr',
#   'wind_direction_compass': 'SW',
#   'created': '2020-04-22T06:27:54.915948Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.375,
#   'max_temp': 13.745000000000001,
#   'the_temp': 11.37,
#   'wind_speed': 4.878764614650441,
#   'wind_direction': 226.0,
#   'air_pressure': 1006.0,
#   'humidity': 49,
#   'visibility': 9.999726596675416,
#   'predictability': 75},
#  {'id': 6531665583144960,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-22T03:27:50.021761Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.75,
#   'max_temp': 12.145,
#   'the_temp': 11.37,
#   'wind_speed': 4.498764614650441,
#   'wind_direction': 261.0,
#   'air_pressure': 1006.0,
#   'humidity': 57,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6310368534069248,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-22T00:27:51.614409Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.07,
#   'max_temp': 10.65,
#   'the_temp': 5.77,
#   'wind_speed': 4.191185874492961,
#   'wind_direction': 276.0,
#   'air_pressure': 995.0,
#   'humidity': 75,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 6458815757156352,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-21T21:27:51.068481Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.07,
#   'max_temp': 10.65,
#   'the_temp': 5.77,
#   'wind_speed': 4.191185874492961,
#   'wind_direction': 276.0,
#   'air_pressure': 995.0,
#   'humidity': 75,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5245224026636288,
#   'weather_state_name': 'Hail',
#   'weather_state_abbr': 'h',
#   'wind_direction_compass': 'N',
#   'created': '2020-04-21T18:27:53.555798Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.88,
#   'max_temp': 10.295,
#   'the_temp': 5.89,
#   'wind_speed': 4.161423685675654,
#   'wind_direction': 352.0,
#   'air_pressure': 1004.0,
#   'humidity': 72,
#   'visibility': 9.676613576712002,
#   'predictability': 82},
#  {'id': 5100067990011904,
#   'weather_state_name': 'Hail',
#   'weather_state_abbr': 'h',
#   'wind_direction_compass': 'N',
#   'created': '2020-04-21T15:27:53.109905Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.88,
#   'max_temp': 10.295,
#   'the_temp': 5.89,
#   'wind_speed': 4.161423685675654,
#   'wind_direction': 352.0,
#   'air_pressure': 1004.0,
#   'humidity': 72,
#   'visibility': 9.676613576712002,
#   'predictability': 82},
#  {'id': 5886596224122880,
#   'weather_state_name': 'Hail',
#   'weather_state_abbr': 'h',
#   'wind_direction_compass': 'N',
#   'created': '2020-04-21T12:27:53.103622Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.88,
#   'max_temp': 10.295,
#   'the_temp': 5.89,
#   'wind_speed': 4.161423685675654,
#   'wind_direction': 352.0,
#   'air_pressure': 1004.0,
#   'humidity': 72,
#   'visibility': 9.676613576712002,
#   'predictability': 82},
#  {'id': 4527590893158400,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-04-21T09:27:52.980890Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 3.05,
#   'max_temp': 10.815000000000001,
#   'the_temp': 5.89,
#   'wind_speed': 3.541423685675654,
#   'wind_direction': 30.50000000000001,
#   'air_pressure': 1004.0,
#   'humidity': 64,
#   'visibility': 9.999726596675416,
#   'predictability': 77},
#  {'id': 5697636487135232,
#   'weather_state_name': 'Showers',
#   'weather_state_abbr': 's',
#   'wind_direction_compass': 'NE',
#   'created': '2020-04-21T06:27:53.199225Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.69,
#   'max_temp': 11.02,
#   'the_temp': 8.53,
#   'wind_speed': 3.5755991012487076,
#   'wind_direction': 52.500000000000014,
#   'air_pressure': 1006.0,
#   'humidity': 54,
#   'visibility': 9.999726596675416,
#   'predictability': 73},
#  {'id': 5413790688477184,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'ESE',
#   'created': '2020-04-21T03:27:53.339675Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.53,
#   'max_temp': 9.24,
#   'the_temp': 8.53,
#   'wind_speed': 1.721198202497415,
#   'wind_direction': 121.0,
#   'air_pressure': 1006.0,
#   'humidity': 47,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 6336877072220160,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'N',
#   'created': '2020-04-21T00:27:52.507494Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.42,
#   'max_temp': 10.92,
#   'the_temp': 9.65,
#   'wind_speed': 2.945299451204963,
#   'wind_direction': 1.0,
#   'air_pressure': 1005.0,
#   'humidity': 47,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 6126731503075328,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'N',
#   'created': '2020-04-20T21:27:53.730576Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.42,
#   'max_temp': 10.92,
#   'the_temp': 9.65,
#   'wind_speed': 2.945299451204963,
#   'wind_direction': 1.0,
#   'air_pressure': 1005.0,
#   'humidity': 47,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 4724993025900544,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-04-20T18:27:56.396637Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.12,
#   'max_temp': 5.25,
#   'the_temp': 4.95,
#   'wind_speed': 2.839666348524616,
#   'wind_direction': 45.0,
#   'air_pressure': 996.0,
#   'humidity': 87,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 4997355692621824,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'NE',
#   'created': '2020-04-20T15:27:56.795716Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.12,
#   'max_temp': 5.25,
#   'the_temp': 4.95,
#   'wind_speed': 2.839666348524616,
#   'wind_direction': 45.0,
#   'air_pressure': 996.0,
#   'humidity': 87,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5992850795790336,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'SSE',
#   'created': '2020-04-20T12:27:57.004340Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.94,
#   'max_temp': 14.56,
#   'the_temp': 13.83,
#   'wind_speed': 2.193440308597789,
#   'wind_direction': 148.0,
#   'air_pressure': 1007.0,
#   'humidity': 44,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 6250892430934016,
#   'weather_state_name': 'Heavy Rain',
#   'weather_state_abbr': 'hr',
#   'wind_direction_compass': 'SSE',
#   'created': '2020-04-20T09:27:56.706292Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 4.94,
#   'max_temp': 14.56,
#   'the_temp': 13.83,
#   'wind_speed': 2.193440308597789,
#   'wind_direction': 148.0,
#   'air_pressure': 1007.0,
#   'humidity': 44,
#   'visibility': None,
#   'predictability': 77},
#  {'id': 5886764499599360,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-20T06:27:56.122840Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.33,
#   'max_temp': 12.22,
#   'the_temp': 11.36,
#   'wind_speed': 1.9013958482462419,
#   'wind_direction': 281.0,
#   'air_pressure': 1014.0,
#   'humidity': 41,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 6287126788308992,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'W',
#   'created': '2020-04-20T03:27:55.833923Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 2.33,
#   'max_temp': 12.22,
#   'the_temp': 11.36,
#   'wind_speed': 1.9013958482462419,
#   'wind_direction': 281.0,
#   'air_pressure': 1014.0,
#   'humidity': 41,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 4568015662219264,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-04-20T00:27:56.863059Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.12,
#   'max_temp': 8.76,
#   'the_temp': 7.68,
#   'wind_speed': 1.373230334844508,
#   'wind_direction': 14.999999999999998,
#   'air_pressure': 1014.0,
#   'humidity': 49,
#   'visibility': None,
#   'predictability': 71},
#  {'id': 6086405786697728,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NNE',
#   'created': '2020-04-19T21:27:55.595543Z',
#   'applicable_date': '2020-04-28',
#   'min_temp': 1.12,
#   'max_temp': 8.76,
#   'the_temp': 7.68,
#   'wind_speed': 1.373230334844508,
#   'wind_direction': 14.999999999999998,
#   'air_pressure': 1014.0,
#   'humidity': 49,
#   'visibility': None,
#   'predictability': 71}]

# %% [markdown]
# #### Задание 3
#
# Сохраните полученные данные в файл `file.json`. Для форматирования файла используйте четыре пробела.

# %%
with open('out/practice.json', 'w') as file:
    json.dump(s, file, indent=4)

# %% [markdown]
# #### Задание 4
#
# Загрузите содержимое файла `file.json` в DataFrame и выведите первые пять строк на экран.

# %%
df = pd.read_json('out/practice.json')
df.head()
# Out:
#                  id weather_state_name weather_state_abbr  \
# 0  4520607007899648            Showers                  s
# 1  5728158202462208            Showers                  s
# 2  5480870762774528            Showers                  s
# 3  5972593918083072            Showers                  s
# 4  5468569036914688            Showers                  s
#
#   wind_direction_compass                      created applicable_date  \
# 0                    WNW  2020-04-28T18:27:32.227221Z      2020-04-28
# 1                    WNW  2020-04-28T15:27:32.320780Z      2020-04-28
# 2                     NW  2020-04-28T12:27:32.389465Z      2020-04-28
# 3                     NW  2020-04-28T09:27:32.493205Z      2020-04-28
# 4                     NW  2020-04-28T06:27:31.423059Z      2020-04-28
#
#    min_temp  max_temp  the_temp  wind_speed  wind_direction  air_pressure  \
# 0     3.670    10.915     9.965    4.550169      297.501335        1009.0
# 1     3.670    10.915     9.920    4.550169      297.501335        1009.0
# 2     3.305    10.225     8.145    4.519929      308.334994        1009.5
# 3     3.195     9.915     8.025    4.555980      308.667384        1009.5
# 4     1.425    10.260     8.765    4.571307      308.667384        1009.5
#
#    humidity  visibility  predictability
# 0        39   12.064543              73
# 1        39   12.064543              73
# 2        51   12.064543              73
# 3        51   10.536902              73
# 4        47   12.849024              73

# %% [markdown]
# ## **18.3** *Чтение из баз данных с помощью pandas и sqlalchemy*

# %% [markdown]
# В этом уроке мы научимся читать данные из разных баз данных и выполнять к ним запросы с помощью библиотеки **`pandas`**
#
# **План урока**
# * Подключение к базам данных с помощью Python
# * Чтение данных из БД с помощью Python и Pandas
#
# ### Подключение к БД
#
# Существует несколько способов подключения к БД. Один из наиболее частых - подключение при помощи библиотек:
# * `sqlalchemy` - для создания подключения
# * `psycopg2` - как драйвер для PostgreSQL\
# (мы будем работать с БД PostgreSQL)
#
# *- нужно установить эти библиотеки, если они ещё не установлены

# %%
import sqlalchemy
import psycopg2

# %% [markdown]
# Для подключения к БД необходимо использовать функцию `create_engine` библиотеки `sqlalchemy`.\
# В качестве обязательного параметра этой функции необходимо передать строку подключения.\
# Эта строка определённого жёстко заданного формата. Разберём эту строку.
#
# - В начале строки указывается диалект языка SQL, который мы планируем использовать. В нашем случае это **PostgreSQL**.
# - Далее, после `+` указывается название драйвера, который мы используем для подключения. У нас это `psycopg2`.\
# Драйвер указывать необязательно, если у вас в системе есть точно только один драйвер. Если же установлено несколько драйверов, то нужно обязательно указать конкретно драйвер.\
# - После этого ставится `://`, далее пишется имя пользователя (`readonly`), `:` пароль (`6hajV34RTQfmxhS`).
# - Сам адрес СУБД пишется через `@`: `dsstudents.skillbox.ru`.
# - После адреса ставится `:` и указывается порт, на котором доступна БД: `5432`\
# (Разные БД имею свои исторически сложившиеся порты, например для PostgreSQL - это 5432. Но часто бывает, что БД находится на каком-то другом порту. Поэтому, лучше всегда уточнять его).
# - После порта ставится слеш `/` и указывается название конкретной БД, к которой мы хотим подключиться: - `db_ds_students`
#
# Функция `create_engine` ждёт объект, который принято называть **`engine`**.\
# Это отправная точка работы с БД, которя позволяет создавть отдельные подключения к БД, анализировать её структуру и т.д.\
# Иными словами, **engine** содержит все действия, которые мы можем совершить с указанной БД.\
# Теперь вызовем у этой переменной метод `connect`, чтобы создать объект подключения к БД и запишем этот объект в другую переменную.

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5432/db_ds_students'

engine = sqlalchemy.create_engine(conn) # создаём движок указанной БД
connect = engine.connect() # создаём коннект к БД

# %% [markdown]
# Итак, мы загрузили БД. Посмотрим теперь какие таблицы нам доступны в этой БД.\
# Для анализа структуры БД используется функция `inspect` библиотеки `sqlalchemy`.\
# Она принимает на вход **`enginge`** и возвращает объект `inspector`.\
# Теперь, используя этот объект, мы можем получать детальную информацию о структуре БД.\
# Например, вызовем метод `get_table_names` чтобы получить список доступных таблиц.

# %%
inspector = sqlalchemy.inspect(engine)
inspector.get_table_names()
# Out:
# ['keywords', 'links', 'ratings', 'exploratory', 'course_purchases', 'joi']

# %% [markdown]
# Итак, мы видим, что нам доступно 6 таблиц. Поработаем с таблицей `course_purchases`.\
# По названию кажется что в ней содержатся сведения о покупке курсов. Убедимся в этом, загрузив её содержимое в **`pandas`** `DataFrame`.\
# Для этого используем функцию `read_sql` из библиотеки **`pandas`**.\
# Эта функция принимает два обязательных аргумента:
# 1. Запрос к БД
# 2. Объект подключения к БД, который мы создали ранее
#
# Вернёмся к запросу. Чтобы загрузить всё содержимое таблицы в датафрейм, нам нужно написать следующий запрос:
# `select * from course_purchases`

# %%
df = pd.read_sql("select * from course_purchases", connect)
df.head(10)
# Out:
#                                 user_id                             course_id  \
# 0                               user_id                             course_id
# 1  ed5da480-57a2-489c-8e68-512155ab9892  fc082ec6-7721-4419-916b-06e4b560b50e
# 2  7ba07e70-f76a-4bbc-9b5d-34265f4f7638  66583e42-987a-4c38-b168-e5ee4772a627
# 3  7ba07e70-f76a-4bbc-9b5d-34265f4f7638  b45874ec-57c7-41e7-a38c-580330a23f50
# 4  8b1752da-599d-413a-a2e9-bc75387b2be9  2d98baac-eb91-4285-99e1-bee66018cd25
# 5  3e3b7b84-65f0-4152-815a-730bec31bb9d  83982097-8179-4ba2-affa-f8aef42fc070
# 6  3e3b7b84-65f0-4152-815a-730bec31bb9d  71a3a64e-b0ec-40ac-9952-a9833900a48e
# 7  8c390b6e-a490-44ac-b974-f5dec7f6970b  b45874ec-57c7-41e7-a38c-580330a23f50
# 8  8c390b6e-a490-44ac-b974-f5dec7f6970b  34bfd77d-4ddd-411b-af91-6d2f92dfb8ce
# 9  1affa6e8-1e05-4728-96ed-dd471f9552d1  590078fa-1cd7-4a1c-b184-839d79f9c54a
#
#    purchase_date             purchase_place
# 0  purchase_date             purchase_place
# 1     2019-03-22               Екатеринбург
# 2     2018-10-28                 Курганинск
# 3     2019-04-06                Владивосток
# 4     2019-03-23                Владивосток
# 5     2019-03-25                    Катайск
# 6     2019-02-25              Североуральск
# 7     2019-03-06                       Сочи
# 8     2019-03-26                Владивосток
# 9     2019-02-16  Александровск-Сахалинский

# %% [markdown]
# Заголовок продублировался. Наверно, так было в изначальной БД. Но мы можем это быстро поправить.

# %%
df = df.iloc[1:,:]
df
# Out:
#                                   user_id  \
# 1    ed5da480-57a2-489c-8e68-512155ab9892
# 2    7ba07e70-f76a-4bbc-9b5d-34265f4f7638
# 3    7ba07e70-f76a-4bbc-9b5d-34265f4f7638
# 4    8b1752da-599d-413a-a2e9-bc75387b2be9
# 5    3e3b7b84-65f0-4152-815a-730bec31bb9d
# ..                                    ...
# 149  395ab5c0-e2f1-4644-974e-29fa4f821b0e
# 150  1b681fe4-5c5a-4c60-b0a3-24241374df95
# 151  1b681fe4-5c5a-4c60-b0a3-24241374df95
# 152  9fc78a49-22bc-4c21-9ee7-1444030c371a
# 153  3e585c7d-52f7-4718-a324-71a5fec75a47
#
#                                 course_id purchase_date   purchase_place
# 1    fc082ec6-7721-4419-916b-06e4b560b50e    2019-03-22     Екатеринбург
# 2    66583e42-987a-4c38-b168-e5ee4772a627    2018-10-28       Курганинск
# 3    b45874ec-57c7-41e7-a38c-580330a23f50    2019-04-06      Владивосток
# 4    2d98baac-eb91-4285-99e1-bee66018cd25    2019-03-23      Владивосток
# 5    83982097-8179-4ba2-affa-f8aef42fc070    2019-03-25          Катайск
# ..                                    ...           ...              ...
# 149  8fba0f0c-e887-4090-84dd-121712a5b86b    2019-04-04  Санкт-Петербург
# 150  f6cc4782-0ec5-4741-8c32-6fec0ad6f14b    2018-05-30           Москва
# 151  3cc8041e-ac78-4c27-899f-c204427d3f63    2019-01-04    Южно-Курильск
# 152  fe32d4f8-9272-4be2-8a74-da8ef0c2bad8    2018-11-17            Пермь
# 153  bdd8cac0-4003-4b22-ab71-9d3272a14121    2018-12-01           Москва
#
# [153 rows x 4 columns]

# %% [markdown]
# Теперь попробуем сделать более сложный запрос с группировкой. Например, посмотрим, сколько курсов было куплено в каждом городе.\
# Мы можем сделать это двумя способами:
# 1. Прямо в **`pandas`**.\
# Для этого у нас уже есть загруженный датафрейм. Используем метод `groupby` по городу и посчитаем количество курсов, проданных в каждом городе с помощью метода `count`.

# %%
df.groupby('purchase_place')['course_id'].count()
# Out:
# purchase_place
# Алдан                         1
# Александровск-Сахалинский     1
# Ангарск                       1
# Анива                         1
# Арзамас                       1
# Аршан (Бурят.)                1
# Асбест                        1
# Аша                           1
# Белогорск (Амур.)             1
# Биробиджан                    1
# Верхний Баскунчак             1
# Владивосток                  25
# Волхов                        1
# Гаврилов-Ям                   1
# Диксон                        1
# Екатеринбург                 15
# Зеленогорск (Ленин.)          1
# Златоуст                      1
# Карабудахкент                 1
# Катайск                       1
# Качканар                      1
# Колпашево                     2
# Костомукша                    1
# Крымск                        1
# Курганинск                    1
# Минусинск                     1
# Москва                       30
# Нефтеюганск                   1
# Орел                          1
# Орск                          1
# Павловский Посад              1
# Пермь                         1
# Печора                        1
# Рославль                      1
# Санкт-Петербург              19
# Саратов                       1
# Сасово                        1
# Североуральск                 1
# Сосногорск                    1
# Сочи                         20
# Тольятти                      1
# Троицк (Моск.)                1
# Тымовское                     1
# Усть-Кулом                    1
# Хужир                         1
# Шатки                         1
# Шенкурск                      1
# Южно-Курильск                 1
# Name: course_id, dtype: int64

# %% [markdown]
# Второй способ заключается в том, чтобы с помощью **SQL** привести все необходимые группировки и потом скачать уже подготовленные данные.\
# Попробуем это сделать.\
# Снова используем метод `read_sql` чтобы выполнить запрос к БД, но вместо простого `SELECT` выполним запрос с группировкой.\
# Выглядеть этот запрос будет так:

# %%
df = pd.read_sql("select purchase_place, count(course_id) from course_purchases group by purchase_place", connect)
df.head(10)
# Out:
#               purchase_place  count
# 0                     Асбест      1
# 1  Александровск-Сахалинский      1
# 2                 Костомукша      1
# 3                       Орел      1
# 4                    Саратов      1
# 5       Зеленогорск (Ленин.)      1
# 6                  Минусинск      1
# 7                     Печора      1
# 8                    Катайск      1
# 9           Павловский Посад      1

# %% [markdown]
# Мы получили такой же датафрейм. Оба способа приводят к одному и тому же рельутату. Так каким же способом лучше пользоваться?\
# Всё зависит от размера данных, которые вы хотите загрузить из БД. Если данных не много, и они помещаются в оперативную память компьютера, то можно пользоваться первым способом. Т.е. сначала загрузить данные в датафрейм, почистить их, а затем преобразовывать.\
# Если же данных много и они не помещаются в памяти, или нужно проводить какие-то сложные группировки или объединения таблиц, тогда имеет смысл сначала подготовить данные в **SQL**, а затем загрузить в датафрейм уже готовые данные.
#
# ### Итоги
#
# На этом уроке мы узнали:
# * Как подключиться к БД\
# Используя библиотеки `sqlalchemy` и `psycopg2`
# * Научились загружать данные из таблицы БД в **`pandas`** `DataFrame`
# * Разобрали, в каких случаях предпочтительнее проводить обработку данных в СУБД,\
# а в каких можно загружать данные целиком и обрабатывать их с помощью **`pandas`**

# %% [markdown]
# ### Практика
#
# #### Задание 1
#
# Подключитесь к базе данных, загрузите содержимое таблицы `course_purchases` в DataFrame и выведите первые 10 строк на экран.

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5432/db_ds_students'

engine = sqlalchemy.create_engine(conn)
connect = engine.connect()

df = pd.read_sql("select * from course_purchases", connect).iloc[1:,:]
df.head(10)
# Out:
#                                  user_id  \
# 1   ed5da480-57a2-489c-8e68-512155ab9892
# 2   7ba07e70-f76a-4bbc-9b5d-34265f4f7638
# 3   7ba07e70-f76a-4bbc-9b5d-34265f4f7638
# 4   8b1752da-599d-413a-a2e9-bc75387b2be9
# 5   3e3b7b84-65f0-4152-815a-730bec31bb9d
# 6   3e3b7b84-65f0-4152-815a-730bec31bb9d
# 7   8c390b6e-a490-44ac-b974-f5dec7f6970b
# 8   8c390b6e-a490-44ac-b974-f5dec7f6970b
# 9   1affa6e8-1e05-4728-96ed-dd471f9552d1
# 10  f7006ad5-9ecd-4606-a8ee-9c730baeb000
#
#                                course_id purchase_date  \
# 1   fc082ec6-7721-4419-916b-06e4b560b50e    2019-03-22
# 2   66583e42-987a-4c38-b168-e5ee4772a627    2018-10-28
# 3   b45874ec-57c7-41e7-a38c-580330a23f50    2019-04-06
# 4   2d98baac-eb91-4285-99e1-bee66018cd25    2019-03-23
# 5   83982097-8179-4ba2-affa-f8aef42fc070    2019-03-25
# 6   71a3a64e-b0ec-40ac-9952-a9833900a48e    2019-02-25
# 7   b45874ec-57c7-41e7-a38c-580330a23f50    2019-03-06
# 8   34bfd77d-4ddd-411b-af91-6d2f92dfb8ce    2019-03-26
# 9   590078fa-1cd7-4a1c-b184-839d79f9c54a    2019-02-16
# 10  187e1d34-1d4b-4ded-8f40-8425974e25d6    2019-01-20
#
#                purchase_place
# 1                Екатеринбург
# 2                  Курганинск
# 3                 Владивосток
# 4                 Владивосток
# 5                     Катайск
# 6               Североуральск
# 7                        Сочи
# 8                 Владивосток
# 9   Александровск-Сахалинский
# 10                       Сочи

# %% [markdown]
# #### Задание 2
#
# Используя DataFrame из предыдущего задания, определите для каждого курса количество пользователей, купивших его. Подсказка: используйте метод groupby.

# %%
df.groupby('course_id').user_id.count()
# Out:
# course_id
# 0172e898-7ddf-4ce9-ae0f-3c26ce949141    2
# 0722fb94-7c6b-41fd-98ea-d4cab87f3655    3
# 0d0d9bbc-c451-41a0-983e-0733046044de    2
# 187e1d34-1d4b-4ded-8f40-8425974e25d6    3
# 196cd844-ffcd-4694-8b94-2983421ddb87    3
# 215c9f43-6046-454b-9f82-e1992f835227    4
# 2466d92a-2a30-4edc-bb8d-bcc2a3891099    3
# 2d98baac-eb91-4285-99e1-bee66018cd25    4
# 31bfef7f-5310-4256-a097-a9c4243654ff    1
# 34bfd77d-4ddd-411b-af91-6d2f92dfb8ce    5
# 3c580c86-9f15-4730-9578-1aca7d19a8ca    2
# 3cc8041e-ac78-4c27-899f-c204427d3f63    4
# 3d2c9fe4-5659-4457-bfd8-6aef1f516374    2
# 44ec7db3-07ab-4b9d-aaef-4b52684510ea    1
# 46ee2954-ec65-4b53-af1e-4a7c7d318873    2
# 493b245c-c7e6-4134-8b58-3264971e097e    9
# 590078fa-1cd7-4a1c-b184-839d79f9c54a    8
# 5b58a4ab-9950-4bdf-bc4d-16225adead8a    8
# 625cd518-8a6f-4bef-9326-10a7e3f9417c    4
# 66583e42-987a-4c38-b168-e5ee4772a627    4
# 71a3a64e-b0ec-40ac-9952-a9833900a48e    1
# 72ddec62-3821-4c9e-a8dd-29e05e7a3210    5
# 83982097-8179-4ba2-affa-f8aef42fc070    3
# 846231ae-5a86-4218-bb3b-d7bb9640d3f1    5
# 86a06a55-2da2-4a37-9a6e-742ba4841fca    4
# 8e730d61-1924-419f-9c0a-c6b7d9688114    4
# 8fba0f0c-e887-4090-84dd-121712a5b86b    1
# 96dcf479-8f6c-4953-804b-a4f2f9c1e2ca    7
# a1307f0a-70c1-40ca-b868-76c428250e02    2
# b45874ec-57c7-41e7-a38c-580330a23f50    6
# b96f0a37-6a38-45cb-9bcf-5940a06d877f    1
# bdd8cac0-4003-4b22-ab71-9d3272a14121    2
# d5720be9-13be-4a66-8d0a-c180099537d2    4
# d575090d-7dc1-4413-98bc-eef102fc79d2    2
# e4a731c1-67d4-4fe1-a908-4a84dd7db821    2
# f384577d-759e-4dd4-84ab-51cbd929a7af    3
# f48a7fc7-40ae-4ede-ab9d-aac7c833c8af    4
# f6cc4782-0ec5-4741-8c32-6fec0ad6f14b    4
# f716b7b6-90af-4b0a-998b-b382beadcfc1    3
# f7d37ce8-2388-4b10-8a7e-55fbd763a5a9    5
# fc082ec6-7721-4419-916b-06e4b560b50e    7
# fe32d4f8-9272-4be2-8a74-da8ef0c2bad8    3
# ff8101ba-a43d-404b-bfeb-a4e5ae4a3dfc    1
# Name: user_id, dtype: int64

# %% [markdown]
# #### Задание 3.
#
# Используя SQL-запрос с группировкой (GROUP BY), определите для каждого курса количество пользователей, купивших его. Результат запроса загрузите в DataFrame и выведите первые 10 строк на экран.

# %%
df = pd.read_sql("select course_id, count(user_id) from course_purchases group by course_id", connect)
df = df[df.course_id != 'course_id'] # отфильтруем строку 27, которая дублирует заголовок (изначально первая строка)
df
# Out:
#                                course_id  count
# 0   fe32d4f8-9272-4be2-8a74-da8ef0c2bad8      3
# 1   f716b7b6-90af-4b0a-998b-b382beadcfc1      3
# 2   b45874ec-57c7-41e7-a38c-580330a23f50      6
# 3   96dcf479-8f6c-4953-804b-a4f2f9c1e2ca      7
# 4   f6cc4782-0ec5-4741-8c32-6fec0ad6f14b      4
# 5   ff8101ba-a43d-404b-bfeb-a4e5ae4a3dfc      1
# 6   b96f0a37-6a38-45cb-9bcf-5940a06d877f      1
# 7   0d0d9bbc-c451-41a0-983e-0733046044de      2
# 8   196cd844-ffcd-4694-8b94-2983421ddb87      3
# 9   8e730d61-1924-419f-9c0a-c6b7d9688114      4
# 10  66583e42-987a-4c38-b168-e5ee4772a627      4
# 11  215c9f43-6046-454b-9f82-e1992f835227      4
# 12  590078fa-1cd7-4a1c-b184-839d79f9c54a      8
# 13  31bfef7f-5310-4256-a097-a9c4243654ff      1
# 14  86a06a55-2da2-4a37-9a6e-742ba4841fca      4
# 15  f48a7fc7-40ae-4ede-ab9d-aac7c833c8af      4
# 16  fc082ec6-7721-4419-916b-06e4b560b50e      7
# 17  3c580c86-9f15-4730-9578-1aca7d19a8ca      2
# 18  44ec7db3-07ab-4b9d-aaef-4b52684510ea      1
# 19  34bfd77d-4ddd-411b-af91-6d2f92dfb8ce      5
# 20  0172e898-7ddf-4ce9-ae0f-3c26ce949141      2
# 21  187e1d34-1d4b-4ded-8f40-8425974e25d6      3
# 22  d5720be9-13be-4a66-8d0a-c180099537d2      4
# 23  46ee2954-ec65-4b53-af1e-4a7c7d318873      2
# 24  625cd518-8a6f-4bef-9326-10a7e3f9417c      4
# 25  71a3a64e-b0ec-40ac-9952-a9833900a48e      1
# 26  a1307f0a-70c1-40ca-b868-76c428250e02      2
# 28  2466d92a-2a30-4edc-bb8d-bcc2a3891099      3
# 29  5b58a4ab-9950-4bdf-bc4d-16225adead8a      8
# 30  2d98baac-eb91-4285-99e1-bee66018cd25      4
# 31  3cc8041e-ac78-4c27-899f-c204427d3f63      4
# 32  f7d37ce8-2388-4b10-8a7e-55fbd763a5a9      5
# 33  bdd8cac0-4003-4b22-ab71-9d3272a14121      2
# 34  e4a731c1-67d4-4fe1-a908-4a84dd7db821      2
# 35  3d2c9fe4-5659-4457-bfd8-6aef1f516374      2
# 36  8fba0f0c-e887-4090-84dd-121712a5b86b      1
# 37  f384577d-759e-4dd4-84ab-51cbd929a7af      3
# 38  0722fb94-7c6b-41fd-98ea-d4cab87f3655      3
# 39  83982097-8179-4ba2-affa-f8aef42fc070      3
# 40  72ddec62-3821-4c9e-a8dd-29e05e7a3210      5
# 41  846231ae-5a86-4218-bb3b-d7bb9640d3f1      5
# 42  493b245c-c7e6-4134-8b58-3264971e097e      9
# 43  d575090d-7dc1-4413-98bc-eef102fc79d2      2

# %% [markdown]
# ## **18.4** *Работа с большими данными - MongoDB*
#
# В этом уроке мы познакомимся с нереляционной БД **MongoDB**
#
# **План урока**
# * Что такое большие данные.\
# Чем они отличаются от других данных
# * Как подключиться к **MongoDB** с помощью Python
# * Как читать данные из **MongoDB**
# * Выполнять различные запросы к **MongoDB**
#
# ### Что такое большие данные
#
# **Big Data** - это разнообразные структурированные и неструктурированные данные большого объёма, требующие быстрой обработки.
#
# Из этого определения можно выделить три свойства BD, т.н. **"V3"**:
# * **Объём (Volume)**.\
# Размер больших данных, который варьируется от гигабайта до терабайта и более
# * **Скорость (Velocity)**.\
# Система обработки больших данных должна быть достаточно быстрой, чтобы обрабатывать поступающие данные почти в режиме реального времени
# * **Разнообразие (Variety)**.\
# Данные могут быть классифицированы по различным типам.\
# Оптимальная система обработки больших данных должна предоставлять функции для\
# манипулирования этими данными без дополнительных действий со стороны клиента.
#
# Наример, **MongoDB** поддерживает операции с геолокацией: таких, как поиск известных точек вблизи координат, указанных в запросе.
#
# ### Что такое **MongoDB**
#
# **MongoDB** - это очень гибкая и масштабируемая **документоориентированная** система управления базами данных.\
# Документоориентированная означает что такие БД в отличие от стандартных реляционных оперируют не строками или таблицами, а документами и коллекциями документов.\
# Фактически, каждый документ можно рассматривать как объект формата JSON.\
# Отличие документа от таблицы в том, что в документе набор полей жёстко не ограничен, т.е. потенциально в каждом документе может быть свой набор полей. И все эти документы могут находиться в одной коллекции.\
# Также, **MongoDB** поддерживает все три свойства больших данных.

# %% [markdown]
# ### Подключение к MongoDB
#
# Для подключения нам понадобится библиотека `pymongo` (тоже требует установки)

# %%
import pymongo

# %% [markdown]
# В начале, мы указывает название диалекта.\
# Поскольку у нас в системе есть только один драйвер подключения, который был установлен вместе с библиотекой 'pymongo', то мы можем его не указывать.\
# Далее вводим - имя пользователя : пароль @ хост : порт.
# Для **MongoDB** стандартный порт 27017, но всегда уточняйте этот момент.\
# При подключении к **MongoDB** название БД указывают немного по-другому: ещё пишут после параметра `?authSource=`.
#
# Теперь создадим подключение к **MongoDB**.\
# Для этого создадим экземпляр класса `MongoClient`, а в конструктор класса передадим строку подключения. И запишем экземпляр клиента в переменную `connect`.\
# Для того, чтобы работать с конкретной базой, нужно обратиться к клиенту как к словарю и передать название требуемой БД как ключ.
# Запишем результат в новую переменную `db`:

# %%
conn = 'mongodb://students:X63673t47Gl03Sq@dsstudents.skillbox.ru:27017/?authSource=movies'

connect = pymongo.MongoClient(conn)
db = connect['movies']

# %% [markdown]
# Теперь посмотрим какие коллекции в этой базе нам доступны. Для этого вызвать метод `list_collection_names` у объекта db

# %%
db.list_collection_names()
# Out:
# ['tags', 'users']

# %% [markdown]
# Нам доступны коллекции `users` и `tags`. Мы будем работать в этом уроке только с коллекцией `tags`.\
# Создадим отдельную переменную под эту коллекцию. Чтобы было проще работать

# %%
tags = db['tags']

# %% [markdown]
# Мы создали переменную tags в коллекции `tags`. Теперь посмотрим на документы, записанные в этой коллекции.
# Мы можем посомотреть на превый документ вызвав у коллекции метод `find_one`

# %%
tags.find_one()
# Out:
# {'_id': ObjectId('5c822402c0669da98bd5081e'), 'id': 931, 'name': 'jealousy'}

# %% [markdown]
# Мы видим документ в формате JSON, содержащий три поля:
# 1. `_id` - это внутренний идентификатор документа в БД
# 2. `id` - это идентификатор тэга
# 3. `name` - имя тэга
#
# Теперь посчитаем сколько документов содержится в коллекции. Для этого вызовем метод `find`, а после него вызовем метод `count`.

# %%
tags.estimated_document_count()
# Out:
# 158680

# %%
users = db['users']
users.estimated_document_count()
# Out:
# 100

# %% [markdown]
# Мы также можем посмотреть на несколько первых записей по аналогии с методом `head` в **`pandas`**.\
# Для этого нам нужно вызвать цепочку методов:\
# сначала метод `find`, который говорит, что нужно найти несколько записей (или даже все),\
# а после него метод `limit`, который ограничивает общее число возвращаемых документов:

# %%
head = tags.find().limit(5)
head

# %% [markdown]
# Как видно, переменная *head* - это объект класса `Cursor`, а не список словарей, как мы ожидали.\
# `Cursor` похож на итератор, т.е. он обеспечивает последовательный доступ к элементам коллекции одни за одним.\
# С `Cursor`'ом в `pymongo` можно работать несколькими способамиЖ
# 1. Если документов планируется много, мы можем обрабатывать их один за одним чтобы не загружать весь большой объём данных в оперативную память.\
# Попробуем вывести каждый элемент на экран:

# %%
for doc in head:
    print(doc)
# Out:
# {'_id': ObjectId('5c822402c0669da98bd5081e'), 'id': 931, 'name': 'jealousy'}
# {'_id': ObjectId('5c822402c0669da98bd5081f'), 'id': 4290, 'name': 'toy'}
# {'_id': ObjectId('5c822402c0669da98bd50820'), 'id': 5202, 'name': 'boy'}
# {'_id': ObjectId('5c822402c0669da98bd50821'), 'id': 6054, 'name': 'friendship'}
# {'_id': ObjectId('5c822402c0669da98bd50822'), 'id': 9713, 'name': 'friends'}

# %% [markdown]
# 2. Этот способ можно применять, если мы используем небольшое количество данных, которое помещается в оперативную память.\
# Мы можем преобразовать курсор к списку и этот списко будет содержать все документы курсора. Попробуем:

# %%
my_list = list(head)
my_list
# Out:
# []

# %% [markdown]
# Список оказался пуст. Это произошло потому что `Cursor` не загружает документы на ваш компьютер, а указывает на подготовленный список документов, находящийся внутри сервера **MongoDB**. Изначально `Cursor` указывает на первый элемент этого списка, а затем, когда мы используем цикл, мы каждую итерацию переставляем `Cursor` на следующий элемент.\
# И когда мы пройдём по всему списку, `Cursor` не будет указывать ни на какой документ. Поэтому, нам нужно ещё раз вызвать методы `find` и `limit` чтобы получить новый `Cursor`.\
# Вызовем их заново и запишем список в новую переменную.

# %%
head = tags.find().limit(5)
my_list = list(head)
my_list
# Out:
# [{'_id': ObjectId('5c822402c0669da98bd5081e'), 'id': 931, 'name': 'jealousy'},
#  {'_id': ObjectId('5c822402c0669da98bd5081f'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd50820'), 'id': 5202, 'name': 'boy'},
#  {'_id': ObjectId('5c822402c0669da98bd50821'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd50822'), 'id': 9713, 'name': 'friends'}]

# %% [markdown]
# Вижим первые 5 документов коллекции. И при этом, документы из этого списка уже никуда не пропадут потому что мы загрузили их себе на компьютер. Можно это проверить.

# %%
my_list
# Out:
# [{'_id': ObjectId('5c822402c0669da98bd5081e'), 'id': 931, 'name': 'jealousy'},
#  {'_id': ObjectId('5c822402c0669da98bd5081f'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd50820'), 'id': 5202, 'name': 'boy'},
#  {'_id': ObjectId('5c822402c0669da98bd50821'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd50822'), 'id': 9713, 'name': 'friends'}]

# %% [markdown]
# Вернёмся к списку.\
# Мы работаем со списком словарей, а значит можем преобразовать его к датафрейму **`pandas`**.
# Для это просто вызовем конструктор `DataFrame`, в который передадим список словарей.\
# И выведем датафрейм на экран.

# %%
df = pd.DataFrame(my_list)
df.head()
# Out:
#                         _id    id        name
# 0  5c822402c0669da98bd5081e   931    jealousy
# 1  5c822402c0669da98bd5081f  4290         toy
# 2  5c822402c0669da98bd50820  5202         boy
# 3  5c822402c0669da98bd50821  6054  friendship
# 4  5c822402c0669da98bd50822  9713     friends

# %% [markdown]
# Теперь мы можем работать с этим датафреймом.\
# Но вернёмся к **MongoDB**. По аналогии с SQL мы можем использовать различные фильтры чтобы ограничить выдачу или найти конкретные документы.\
# Например, мы хотим найти все тэги с индентификатором 4290.\
# Фильтры в **MongoDB** выполняют ту же самую функцию, что и `WHERE` в SQL, однако, строится по-другому.
# В **MongoDB** фильтр - это **словарь**, который чаще всего строится следующим образом:
# * **ключ фильтра** - это название поля в документах, по которому нужно фильтровать (в нашем случае это `id`)
# * **значение** - это ещё один словарь, в котором *ключ* - это операция сравнения (равенство/неравенство/включение и т.п),\
# а *значение* - это, собственно, значение, с которым мы будем сравнивать информацию в полях.
#
# Поскольку мы хотим найти тэг, идентификатор которого равен 4290, то в качестве ключа передадим `$eq`, а в качестве значения - 4290.\
# Теперь весь этот словарь передадим в функцию `find` в качестве параметра и выполним ячейку.

# %%
tags.find({'id': {'$eq': 4290}}, {'_id': True})

# %% [markdown]
# Мы снова получили `Cursor`. И теперь преобразуем его к списку:

# %%
head = tags.find({'id': {'$eq': 4290}})
my_list = list(head)
my_list
# Out:
# [{'_id': ObjectId('5c822402c0669da98bd5081f'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd5143a'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd52bdb'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd5338c'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd53a7b'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd5416e'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd56db6'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd59399'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd5971a'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd5b9e5'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd5d698'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd5fe50'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd61622'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd62719'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd648c0'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd6563a'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd66d5f'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822402c0669da98bd6c705'), 'id': 4290, 'name': 'toy'},
#  {'_id': ObjectId('5c822403c0669da98bd72a48'), 'id': 4290, 'name': 'toy'}]

# %% [markdown]
# На экране появился список документов, которые содержат тэг 4290.\
# Также мы можем ограничить список полей, которые должны содержать документы из выдачи.\
# Например, предположим что в предыдущем примере нам нужен только внутренний идентификатор документа.\
# Для ограничения списка полей существует проекция.\
# Это ещё один словарь, который в качестве ключей содержит название поля, а в качестве значений - булеву переменную - включать ли данное поле в выдачу.\
# Нам нужно создать прекцию, содержащую только поле `_id`. Создадим соответствующий словарь и передадим его в качестве второго параметра в функцию `find`.

# %%
head = tags.find({'id': {'$eq': 4290}}, {'_id': True})
my_list = list(head)
my_list
# Out:
# [{'_id': ObjectId('5c822402c0669da98bd5081f')},
#  {'_id': ObjectId('5c822402c0669da98bd5143a')},
#  {'_id': ObjectId('5c822402c0669da98bd52bdb')},
#  {'_id': ObjectId('5c822402c0669da98bd5338c')},
#  {'_id': ObjectId('5c822402c0669da98bd53a7b')},
#  {'_id': ObjectId('5c822402c0669da98bd5416e')},
#  {'_id': ObjectId('5c822402c0669da98bd56db6')},
#  {'_id': ObjectId('5c822402c0669da98bd59399')},
#  {'_id': ObjectId('5c822402c0669da98bd5971a')},
#  {'_id': ObjectId('5c822402c0669da98bd5b9e5')},
#  {'_id': ObjectId('5c822402c0669da98bd5d698')},
#  {'_id': ObjectId('5c822402c0669da98bd5fe50')},
#  {'_id': ObjectId('5c822402c0669da98bd61622')},
#  {'_id': ObjectId('5c822402c0669da98bd62719')},
#  {'_id': ObjectId('5c822402c0669da98bd648c0')},
#  {'_id': ObjectId('5c822402c0669da98bd6563a')},
#  {'_id': ObjectId('5c822402c0669da98bd66d5f')},
#  {'_id': ObjectId('5c822402c0669da98bd6c705')},
#  {'_id': ObjectId('5c822403c0669da98bd72a48')}]

# %% [markdown]
# Теперь в выдаче остались только внутренние идентификаторы `_id`
#
# ### Итоги
#
# На это уроке мы узнали:
# * Как подключиться к **MongoDB** из Notebook'а используя библиотеку `pymongo`
# * Научились загружать данные из коллекции **MongoDB** в **`pandas`** `DataFrame`
# * Научились выполнять поиск по коллекциям

# %% [markdown]
# ### Практика
#
# #### Задание 1
#
# Подключитесь к коллекции `tags` MongoDB и выведите первый документ на экран

# %%
conn = 'mongodb://students:X63673t47Gl03Sq@dsstudents.skillbox.ru:27017/?authSource=movies'

connect = pymongo.MongoClient(conn)
db = connect['movies']
tags = db['tags']

tags.find_one()
# Out:
# {'_id': ObjectId('5c822402c0669da98bd5081e'), 'id': 931, 'name': 'jealousy'}

# %% [markdown]
# #### Задание 2
#
# Найдите документы, в которых имя тега (поле `name`) 'friendship', преобразуйте курсор в список и выведите содержимое списка на экран

# %%
head = tags.find({'name': {'$eq': 'friendship'}})
my_list = list(head)
my_list
# Out:
# [{'_id': ObjectId('5c822402c0669da98bd50821'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd50911'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd50a72'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd50c39'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd50dc9'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd510d4'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5111c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd51138'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd51141'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5115b'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5121f'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd51449'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd51492'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd514bc'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd51503'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd51631'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd516f8'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5177d'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd51789'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd51a1a'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd51a67'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd51b07'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd51c0e'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd51c34'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd51c99'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd520a1'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd52117'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5212a'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5267c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd527bf'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd52855'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd52984'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd52a49'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd52cc7'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd52d30'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd52dd8'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd52e4f'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd52f6a'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd532a2'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5335f'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd53506'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd536ac'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd537e1'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd53857'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd53de0'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd53ef4'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd53f71'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd54130'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd543db'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd54542'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd54649'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd54663'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd54738'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd54a6c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd54b14'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd54b5d'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd54e2a'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd54f11'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd55002'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd550aa'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd552a6'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd556c2'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5598a'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd55ac7'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd55b6b'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd55c96'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd55e22'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd55f68'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd560fa'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd561dc'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd567bc'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd567d8'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5686f'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd56b38'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd56b9a'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd56ccf'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd56df4'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd56e23'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd57088'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd57225'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd57259'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5727b'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd57369'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd573d3'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5792e'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd579b1'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd57a27'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd57b46'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd57c90'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd57d31'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd57e8b'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd57fac'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd580cd'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd58146'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd582d3'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5847e'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd58596'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd585d4'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd587f5'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd589f2'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd58ac7'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd58b1e'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd58d0b'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd58d88'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5915a'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5921a'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd59450'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd59517'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd59649'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd596a0'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5984c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd59961'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd59a54'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd59a8e'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd59fd8'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5a0fe'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5a4bd'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5a777'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5a7f8'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5a7ff'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5b15e'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5b221'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5b2f1'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5b4d1'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5b76d'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5bac6'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5bdf4'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5bf8a'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5c1e5'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5c2d1'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5c48f'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5c724'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5cfac'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5cff7'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5d05f'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5d18f'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5d648'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5d6b5'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5d738'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5d9c3'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5da86'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5df46'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5df76'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5e113'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5e1da'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5e208'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5e3aa'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5e3e0'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5e4c0'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5e73b'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5e82b'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5e8b0'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5eaea'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5ec66'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5ede1'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5ef7b'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5f23c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5f362'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5f3c4'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5f84d'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5fba4'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5fbdd'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5fcf4'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5fd1e'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5fe2b'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd5ff16'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd600af'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd601fb'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd60401'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6052b'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd60638'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6069b'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd60774'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd60a43'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd60abe'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd60af8'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd60b3f'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd60eaf'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd60f06'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd60f33'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd60f71'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6109c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd61125'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd61288'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd612d1'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd61395'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6171e'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd619e0'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd61c32'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd61ca5'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd61d3a'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd61d89'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd61ea9'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd61f63'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd622a4'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd622d6'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd623fa'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6269f'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd627f0'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd628f4'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd629ff'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd62a40'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd62af1'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd62b28'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd62b95'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd62d19'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd62e8c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd62ee7'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd63498'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd63553'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd63786'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd63acd'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd63ce9'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd63e47'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd64061'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd640e4'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd642ce'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd642f9'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd64388'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd643a3'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd64400'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6451d'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd645a4'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd646d9'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6478d'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd64821'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd64a2c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd64c27'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd64c83'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd64f6f'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd64fbd'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd65194'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd654b3'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd654c6'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd658cc'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd659b3'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd659db'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd65a7e'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd65cb0'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd65ddb'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd65fe6'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd660d5'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6620b'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd66384'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6679c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6680f'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd66824'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd66e5d'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd66f8e'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd66fa8'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd67011'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd670c3'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd671e0'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd67239'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6725e'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd67269'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6749a'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd67563'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6765b'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd67851'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd67aaa'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd67ae1'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd67b90'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd67c92'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd67e4d'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd682b7'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd68511'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6867d'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6897b'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6899c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd68af6'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd68ea2'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd68ee3'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd68f54'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd68fd3'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd69021'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd690dc'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6916c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd695ad'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd69f89'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6a117'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6a200'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6a217'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6a346'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6a478'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6a53f'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6a624'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6a6e0'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6a730'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6a887'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6a9a5'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6a9c5'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6aa32'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6ac16'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6ac1b'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6aebc'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6b093'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6b0af'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6b519'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6b55f'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6b5bd'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6b5d9'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6b782'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6b7d1'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6b8db'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6b900'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6baa9'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6bd6c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6bdbc'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6bdef'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6bf0f'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6c03c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6c577'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6c64d'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6ca9d'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6ce36'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6ced3'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6d1ae'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6d421'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6d630'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822402c0669da98bd6d904'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd6dc02'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd6e1d8'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd6e2f0'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd6e6a5'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd6e6b3'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd6e9b4'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd6eb70'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd6ed00'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd6f030'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd6f0bd'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd6f931'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd6fa46'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd6fb35'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd6fc55'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd7002a'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd70300'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd70467'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd706e4'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd708db'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd70e52'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd70eed'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd70f21'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd7169c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd7169f'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd71955'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd71a46'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd71b43'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd71d83'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd71e81'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd7203f'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd721ec'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd722e3'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd72527'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd72638'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd727e0'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd72a32'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd72a49'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd72ab2'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd72b24'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd72cbf'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd72d68'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd72daa'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd73009'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd73193'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd731a3'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd7326c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd7344c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd734fa'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd7387e'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd738cd'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd73965'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd73b91'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd73c34'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd73ffc'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd74014'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd740cf'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd74156'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd741ef'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd7420d'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd74385'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd743b2'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd743e3'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd74994'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd74a2a'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd74c98'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd74da2'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd74f96'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd750fb'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd7525c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd7539c'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd753bc'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd75502'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd75560'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd75568'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd75707'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd75a31'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd75bb9'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd75d55'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd75d70'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd75d75'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd75e1a'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd762e5'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd76350'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd764d2'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd7668d'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd769e6'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd76d3b'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd76d7f'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd77080'),
#   'id': 6054,
#   'name': 'friendship'},
#  {'_id': ObjectId('5c822403c0669da98bd770eb'),
#   'id': 6054,
#   'name': 'friendship'}]

# %% [markdown]
# #### Задание 3
#
# Преобразуйте список документов в pandas DataFrame и выведите первые 5 строк на экран

# %%
df = pd.DataFrame(my_list)
df.head()
# Out:
#                         _id    id        name
# 0  5c822402c0669da98bd50821  6054  friendship
# 1  5c822402c0669da98bd50911  6054  friendship
# 2  5c822402c0669da98bd50a72  6054  friendship
# 3  5c822402c0669da98bd50c39  6054  friendship
# 4  5c822402c0669da98bd50dc9  6054  friendship

# %% [markdown]
# ## Итоги
#
# В этом модуле мы научились:
# * Читать данные в формате JSON как из веб-сервисов, так и из файлов\
# А также преобразовывать их в **pandas** `DataFrame` и сохранять в файлы формата JSON
# * Узнали как читать данные из реляционных баз данных используя **Pandas**
# * Познакомились с миром Больших данных, а конкретно - с БД **MongoDB**
#
# ## *Выводы*
#
# * Формат JSON часто используется для обмена данными между клиентом и сервером
# * **Pandas** и **SQLAlchemy** позволяют читать данные напрямую из баз данных
# * Работа с большими данными отличается от работы c обычными БД
